# %% [markdown]
# #  Imports

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Flatten, Activation, Dropout, MaxPooling2D, BatchNormalization, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Precision, Recall, AUC
from tensorflow.keras.applications import Xception, EfficientNetB0
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix, accuracy_score

from sklearn.metrics import f1_score


import seaborn as sns
import matplotlib.pyplot as plt
import os

# %% [markdown]
# # Function Definitions

# %%
def train_val_generators(train_dir, val_dir):
    train_gen = ImageDataGenerator(rescale=1/255., horizontal_flip=True, vertical_flip=True, zoom_range=0.2)
    train_generator = train_gen.flow_from_directory(directory=train_dir, target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode='categorical')

    val_gen = ImageDataGenerator(rescale=1/255.)
    val_generator = val_gen.flow_from_directory(directory=val_dir, target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode='categorical')

    return train_generator, val_generator


def train_model(model, train_generator, val_generator, epochs=15):
    callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)

    history = model.fit(train_generator, validation_data=val_generator, epochs=epochs, callbacks=[callback])

    return history

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

def train_val_generators_shear(train_dir, val_dir):
    train_datagen = ImageDataGenerator(
        rescale=1./255,
        rotation_range=20,
        width_shift_range=0.2,
        height_shift_range=0.2,
        shear_range=0.2,
        horizontal_flip=True,
        vertical_flip=True,
        fill_mode='nearest'
    )

    val_datagen = ImageDataGenerator(rescale=1./255.)

    train_generator = train_datagen.flow_from_directory(
        directory=train_dir,
        target_size=IMG_SIZE,
        batch_size=BATCH_SIZE,
        class_mode='categorical'
    )

    val_generator = val_datagen.flow_from_directory(
        directory=val_dir,
        target_size=IMG_SIZE,
        batch_size=BATCH_SIZE,
        class_mode='categorical'
    )

    return train_generator, val_generator

# %%
import seaborn as sns
import matplotlib.pyplot as plt

import seaborn as sns
import matplotlib.pyplot as plt

def plot_training_history(history):
    # Plotear el historial de entrenamiento
    eps = range(len(history.history["loss"]))
    plt.figure(figsize=(10, 6))
    plt.plot(eps, history.history["loss"])
    plt.plot(eps, history.history["val_loss"])
    plt.legend(["loss", "val_loss"])
    plt.title('Training History - Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.show()

    # Plotear la precisión
    plt.figure(figsize=(10, 6))
    plt.plot(eps, history.history["accuracy"])
    plt.plot(eps, history.history["val_accuracy"])
    plt.legend(["accuracy", "val_accuracy"])
    plt.title('Training History - Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.show()

def check_precision(model, test_generator):
    # Asignar e imprimir etiquetas
    test_labels, pred_labels = assign_labels(test_generator, model, print_info=False)

    # Imprimir la matriz de confusión y la precisión
    cm = confusion_matrix(test_labels, pred_labels)
    accuracy = accuracy_score(test_labels, pred_labels)

    print("Matriz de Confusión:")
    print(cm)
    print("Precisión:", accuracy)
    return cm

# %%
def plot_confusion_matrix(cm, classes):
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', xticklabels=classes, yticklabels=classes)
    plt.title('Matriz de Confusión')
    plt.xlabel('Etiquetas Predichas')
    plt.ylabel('Etiquetas Verdaderas')
    plt.show()

# %% [markdown]
# # Configuracion inicial

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Directorio base después de montar el drive
base_path = '/content/drive/My Drive/DataSet'

# Listar archivos en el directorio base
files = os.listdir(base_path)

path_root = '/content/drive/My Drive/DataSet'

valid_dir = os.path.join(path_root, 'val')
train_dir = os.path.join(path_root, 'train')
test_dir = os.path.join(path_root, 'test')

# %%
bc_types = [file for file in os.listdir(train_dir) if os.path.isdir(os.path.join(train_dir, file))]
print("Types: ", bc_types)

# to encode labels
bc_dict = {'InSitu': 3, 'Benign': 2, 'Normal': 1, 'Invasive': 4}
print("Encode: ", bc_dict)

# to decode labels
dict_bc = {1: "Normal", 2: "Benign", 3: "InSitu", 4: "Invasive"}
print("Decode: ", dict_bc)

classes = [dict_bc[i] for i in sorted(dict_bc.keys())]
# Out:
# Types:  ['InSitu', 'Normal', 'Invasive', 'Benign']
# Encode:  {'InSitu': 3, 'Benign': 2, 'Normal': 1, 'Invasive': 4}
# Decode:  {1: 'Normal', 2: 'Benign', 3: 'InSitu', 4: 'Invasive'}

# %%
# Set IMG_SIZE and BATCH_SIZE
IMG_SIZE = (512, 512)
BATCH_SIZE = 8
NUM_CLASES = 4

# %%
import imghdr  # Importar el módulo imghdr para verificar el tipo de imagen

# Calcular el rango de píxeles en lugar de asumir que es 255
pixel_min = float('inf')  # Inicializar con un valor grande
pixel_max = float('-inf')  # Inicializar con un valor pequeño

# Iterar sobre las imágenes en el conjunto de entrenamiento para encontrar el rango real
for root, dirs, files in os.walk(train_dir):
    for file in files:
        img_path = os.path.join(root, file)

        # Verificar si el archivo es una imagen
        if imghdr.what(img_path) is not None:
            img = plt.imread(img_path)
            img_min = np.min(img)
            img_max = np.max(img)
            pixel_min = min(pixel_min, img_min)
            pixel_max = max(pixel_max, img_max)

# %%
pixel_min
# Out:
# 0

# %%
train_generator, val_generator = train_val_generators(train_dir, valid_dir)   # create image generators to feed images to the model
# Out:
# Found 236 images belonging to 4 classes.
# Found 81 images belonging to 4 classes.

# %%
train_generator_2, val_generator_2 = train_val_generators_shear(train_dir, valid_dir)   # create image generators to feed images to the model
# Out:
# Found 236 images belonging to 4 classes.
# Found 81 images belonging to 4 classes.

# %% [markdown]
# # Create models

# %%
#Para poder incluir el valor f1 en el entrenamiento del modelo creamos las siguientes
#funciones para añadirlo como una función siguiendo la referencia del sigueinte enlace
#https://datascience.stackexchange.com/questions/45165/how-to-get-accuracy-f1-precision-and-recall-for-a-keras-model

from keras import backend as K
def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %% [markdown]
# ## ENTRENAMIENTO DE MODELOS

# %%
from tensorflow.keras import layers, models
from tensorflow.keras.applications import Xception, EfficientNetB0, InceptionV3, VGG16, VGG19, ResNet50
from tensorflow.keras.optimizers import Adam
import tensorflow as tf

# %%
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers, models

def build_model_with_base(base_model, num_classes, img_size1, img_size2, learning_rate, freeze_layers=None, additional_layers=None):
    inputs = layers.Input(shape=(img_size1, img_size2, 3))

    # Configurar el modelo base
    base_model = base_model(include_top=False, input_tensor=inputs, weights="imagenet")

    # Congelar todas las capas si freeze_layers es None
    if freeze_layers == 'all':
        for layer in base_model.layers:
            layer.trainable = False
    elif isinstance(freeze_layers, int):
        # Congelar las primeras 'freeze_layers' capas
        for layer in base_model.layers[:freeze_layers]:
            layer.trainable = False
    else:
        raise ValueError("El argumento freeze_layers debe ser 'all' o un entero.")

    # Construir el modelo con el modelo base
    x = base_model.output

    # Agregar capas adicionales si se proporcionan
    if additional_layers:
        for layer in additional_layers:
            x = layer(x)

    # Agregar capas de convolución adicionales
    x = layers.Conv2D(64, (3, 3), activation="relu", padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D(2, 2)(x)

    x = layers.Conv2D(128, (3, 3), activation="relu", padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D(2, 2)(x)

    # Agregar capas finales
    x = layers.Conv2D(32, (3, 3), activation="relu", padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D(2, 2)(x)

    # Agregar GlobalAveragePooling2D
    x = GlobalAveragePooling2D()(x)

    x = layers.Dropout(0.3)(x)
    x = Dense(64, activation="relu")(x)
    outputs = Dense(num_classes, activation="softmax")(x)

    # Compilar el modelo
    model = models.Model(inputs, outputs, name=f"CustomModel_{base_model.name}")
    optimizer = Adam(learning_rate=learning_rate)
    model.compile(optimizer=optimizer, loss="categorical_crossentropy", metrics=['acc', f1_m, precision_m, recall_m])

    return model

# %%
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers, models

def build_model_with_base_v2(base_model, num_classes, img_size1, img_size2, learning_rate, freeze_layers=None, additional_layers=None):
    inputs = layers.Input(shape=(img_size1, img_size2, 3))
    base_model = base_model(include_top=False, input_tensor=inputs, weights="imagenet")

    # Congelar todas las capas si freeze_layers es None
    if freeze_layers == 'all':
        for layer in base_model.layers:
            layer.trainable = False
    elif isinstance(freeze_layers, int):
        # Congelar las primeras 'freeze_layers' capas
        for layer in base_model.layers[:freeze_layers]:
            layer.trainable = False
    else:
        raise ValueError("El argumento freeze_layers debe ser 'all' o un entero.")

    # Construir el modelo con el modelo base

    x = base_model.output

    # Reducir el número de capas de convolución
    x = layers.Conv2D(64, (3, 3), activation="relu", padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D(2, 2)(x)

    # Agregar una capa de convolución adicional
    x = layers.Conv2D(128, (3, 3), activation="relu", padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D(2, 2)(x)

    # Agregar GlobalAveragePooling2D
    x = layers.GlobalAveragePooling2D()(x)

    x = layers.Dropout(0.3)(x)
    x = layers.Dense(64, activation="relu")(x)
    outputs = layers.Dense(num_classes, activation="softmax")(x)

    # Compilar el modelo
    model = models.Model(inputs, outputs, name=f"CustomModel_{base_model.name}")
    optimizer = Adam(learning_rate=learning_rate)
    model.compile(optimizer=optimizer, loss="categorical_crossentropy", metrics=['acc', f1_m, precision_m, recall_m])

    return model

# %%
xception_model_preprocessed = build_model_with_base(Xception, NUM_CLASES, IMG_SIZE[0], IMG_SIZE[1],0.00005,0)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 [==============================] - 0s 0us/step

# %%
xception_model_preprocessed_2 = build_model_with_base_v2(Xception, NUM_CLASES, IMG_SIZE[0], IMG_SIZE[1],0.00005,0)

# %% [markdown]
# # Entrenamiento de modelos

# %%
# Specify the directory to save the models
save_dir = '/content/drive/My Drive/SavedModels'

# Ensure the directory exists, create it if necessary
os.makedirs(save_dir, exist_ok=True)

# %%
callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)   # limitation to stop somewhere early

# %%
print("\n[INFO] Ready to train. Training is starting!\n")
BATCH_SIZE = 8
# Out:
# [INFO] Ready to train. Training is starting!

# %%
# Model training for Xception
# %%time

hist_xception_preprocessed = xception_model_preprocessed.fit(train_generator, validation_data=val_generator, epochs=50)
# Guardar modelos en formato H5
xception_model_preprocessed.save(os.path.join(save_dir, 'xception_model_preprocessed.h5'))
# Out:
# Epoch 1/50
# 30/30 [==============================] - 108s 2s/step - loss: 1.9011 - acc: 0.2542 - f1_m: 0.2207 - precision_m: 0.2559 - recall_m: 0.1958 - val_loss: 1.3860 - val_acc: 0.2716 - val_f1_m: 0.0202 - val_precision_m: 0.0909 - val_recall_m: 0.0114
# Epoch 2/50
# 30/30 [==============================] - 21s 676ms/step - loss: 1.6048 - acc: 0.2924 - f1_m: 0.2395 - precision_m: 0.2948 - recall_m: 0.2042 - val_loss: 1.3506 - val_acc: 0.2716 - val_f1_m: 0.0768 - val_precision_m: 0.2727 - val_recall_m: 0.0455
# Epoch 3/50
# 30/30 [==============================] - 21s 716ms/step - loss: 1.3244 - acc: 0.3814 - f1_m: 0.2810 - precision_m: 0.4294 - recall_m: 0.2125 - val_loss: 1.3022 - val_acc: 0.2716 - val_f1_m: 0.1516 - val_precision_m: 0.3409 - val_recall_m: 0.1023
# Epoch 4/50
# 30/30 [==============================] - 21s 690ms/step - loss: 1.2284 - acc: 0.4322 - f1_m: 0.3472 - precision_m: 0.5187 - recall_m: 0.2708 - val_loss: 1.2175 - val_acc: 0.3951 - val_f1_m: 0.3716 - val_precision_m: 0.8561 - val_recall_m: 0.2500
# Epoch 5/50
# 30/30 [==============================] - 22s 710ms/step - loss: 1.0947 - acc: 0.5254 - f1_m: 0.3957 - precision_m: 0.6100 - recall_m: 0.3042 - val_loss: 1.0724 - val_acc: 0.5309 - val_f1_m: 0.4002 - val_precision_m: 0.7636 - val_recall_m: 0.2841
# Epoch 6/50
# 30/30 [==============================] - 21s 694ms/step - loss: 1.0334 - acc: 0.5636 - f1_m: 0.4330 - precision_m: 0.6311 - recall_m: 0.3417 - val_loss: 1.0273 - val_acc: 0.5432 - val_f1_m: 0.4205 - val_precision_m: 0.7439 - val_recall_m: 0.3068
# Epoch 7/50
# 30/30 [==============================] - 21s 692ms/step - loss: 0.9057 - acc: 0.6610 - f1_m: 0.5659 - precision_m: 0.7461 - recall_m: 0.4625 - val_loss: 0.9578 - val_acc: 0.5309 - val_f1_m: 0.4750 - val_precision_m: 0.7470 - val_recall_m: 0.3636
# Epoch 8/50
# 30/30 [==============================] - 21s 694ms/step - loss: 0.7837 - acc: 0.6992 - f1_m: 0.6127 - precision_m: 0.7862 - recall_m: 0.5208 - val_loss: 0.9109 - val_acc: 0.6296 - val_f1_m: 0.5577 - val_precision_m: 0.7742 - val_recall_m: 0.4545
# Epoch 9/50
# 30/30 [==============================] - 22s 713ms/step - loss: 0.7131 - acc: 0.7500 - f1_m: 0.7013 - precision_m: 0.8317 - recall_m: 0.6125 - val_loss: 0.8942 - val_acc: 0.6049 - val_f1_m: 0.5477 - val_precision_m: 0.7058 - val_recall_m: 0.4545
# 30/30 [==============================] - 22s 716ms/step - loss: 0.2536 - acc: 0.9322 - f1_m: 0.9296 - precision_m: 0.9502 - recall_m: 0.9125 - val_loss: 0.4563 - val_acc: 0.8765 - val_f1_m: 0.8833 - val_precision_m: 0.9058 - val_recall_m: 0.8636
# Epoch 31/50
# 30/30 [==============================] - 22s 724ms/step - loss: 0.1813 - acc: 0.9619 - f1_m: 0.9539 - precision_m: 0.9583 - recall_m: 0.9500 - val_loss: 0.4722 - val_acc: 0.8519 - val_f1_m: 0.8657 - val_precision_m: 0.8826 - val_recall_m: 0.8523
# Epoch 32/50
# 30/30 [==============================] - 23s 738ms/step - loss: 0.2440 - acc: 0.9492 - f1_m: 0.9443 - precision_m: 0.9629 - recall_m: 0.9292 - val_loss: 0.5580 - val_acc: 0.8395 - val_f1_m: 0.8298 - val_precision_m: 0.8597 - val_recall_m: 0.8068
# Epoch 33/50
# 30/30 [==============================] - 23s 739ms/step - loss: 0.2121 - acc: 0.9449 - f1_m: 0.9477 - precision_m: 0.9599 - recall_m: 0.9375 - val_loss: 0.5368 - val_acc: 0.8519 - val_f1_m: 0.8657 - val_precision_m: 0.8826 - val_recall_m: 0.8523
# Epoch 34/50
# 30/30 [==============================] - 23s 737ms/step - loss: 0.1789 - acc: 0.9534 - f1_m: 0.9559 - precision_m: 0.9772 - recall_m: 0.9417 - val_loss: 0.5357 - val_acc: 0.8642 - val_f1_m: 0.8792 - val_precision_m: 0.8983 - val_recall_m: 0.8636
# Epoch 35/50
# 30/30 [==============================] - 23s 735ms/step - loss: 0.2132 - acc: 0.9407 - f1_m: 0.9280 - precision_m: 0.9415 - recall_m: 0.9167 - val_loss: 0.5523 - val_acc: 0.8272 - val_f1_m: 0.8394 - val_precision_m: 0.8636 - val_recall_m: 0.8182
# Epoch 36/50
# 30/30 [==============================] - 22s 732ms/step - loss: 0.1782 - acc: 0.9492 - f1_m: 0.9413 - precision_m: 0.9607 - recall_m: 0.9250 - val_loss: 0.6300 - val_acc: 0.7531 - val_f1_m: 0.7856 - val_precision_m: 0.8155 - val_recall_m: 0.7614
# Epoch 37/50
# 30/30 [==============================] - 23s 747ms/step - loss: 0.1743 - acc: 0.9619 - f1_m: 0.9489 - precision_m: 0.9619 - recall_m: 0.9375 - val_loss: 0.5895 - val_acc: 0.7778 - val_f1_m: 0.8173 - val_precision_m: 0.8442 - val_recall_m: 0.7955
# Epoch 38/50
# 30/30 [==============================] - 22s 707ms/step - loss: 0.1561 - acc: 0.9661 - f1_m: 0.9572 - precision_m: 0.9702 - recall_m: 0.9458 - val_loss: 0.4789 - val_acc: 0.8765 - val_f1_m: 0.8848 - val_precision_m: 0.8961 - val_recall_m: 0.8750
# Epoch 39/50
# 30/30 [==============================] - 22s 715ms/step - loss: 0.2027 - acc: 0.9576 - f1_m: 0.9293 - precision_m: 0.9625 - recall_m: 0.9042 - val_loss: 0.4464 - val_acc: 0.9012 - val_f1_m: 0.9045 - val_precision_m: 0.9253 - val_recall_m: 0.8864
# Epoch 40/50
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# CPU times: user 24min 38s, sys: 2min 52s, total: 27min 30s
# Wall time: 19min 39s

# %%
xception_model_generator_2 = build_model_with_base(Xception, NUM_CLASES, IMG_SIZE[0], IMG_SIZE[1],0.00005,0)

hist_xception_generator_2 = xception_model_generator_2.fit(train_generator_2, validation_data=val_generator_2, epochs=50)
# Out:
# Epoch 1/50
# 30/30 [==============================] - 48s 828ms/step - loss: 1.6215 - acc: 0.2881 - f1_m: 0.1905 - precision_m: 0.2756 - recall_m: 0.1500 - val_loss: 1.3686 - val_acc: 0.2840 - val_f1_m: 0.0000e+00 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# Epoch 2/50
# 30/30 [==============================] - 24s 770ms/step - loss: 1.3608 - acc: 0.3941 - f1_m: 0.2584 - precision_m: 0.4067 - recall_m: 0.1917 - val_loss: 1.3416 - val_acc: 0.2963 - val_f1_m: 0.0000e+00 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# Epoch 3/50
# 30/30 [==============================] - 24s 781ms/step - loss: 1.1814 - acc: 0.4407 - f1_m: 0.3607 - precision_m: 0.5850 - recall_m: 0.2667 - val_loss: 1.2905 - val_acc: 0.3333 - val_f1_m: 0.0000e+00 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# Epoch 4/50
# 30/30 [==============================] - 24s 783ms/step - loss: 1.0548 - acc: 0.5297 - f1_m: 0.4000 - precision_m: 0.7300 - recall_m: 0.2875 - val_loss: 1.2423 - val_acc: 0.3333 - val_f1_m: 0.1877 - val_precision_m: 0.4242 - val_recall_m: 0.1250
# Epoch 5/50
# 30/30 [==============================] - 23s 767ms/step - loss: 0.9839 - acc: 0.5805 - f1_m: 0.4613 - precision_m: 0.7133 - recall_m: 0.3542 - val_loss: 1.1604 - val_acc: 0.4321 - val_f1_m: 0.2127 - val_precision_m: 0.5758 - val_recall_m: 0.1364
# Epoch 6/50
# 30/30 [==============================] - 24s 795ms/step - loss: 0.9161 - acc: 0.6229 - f1_m: 0.5182 - precision_m: 0.7894 - recall_m: 0.4000 - val_loss: 1.0410 - val_acc: 0.5926 - val_f1_m: 0.1958 - val_precision_m: 0.5152 - val_recall_m: 0.1250
# Epoch 7/50
# 30/30 [==============================] - 24s 794ms/step - loss: 0.8370 - acc: 0.6864 - f1_m: 0.6183 - precision_m: 0.8100 - recall_m: 0.5125 - val_loss: 0.9828 - val_acc: 0.6420 - val_f1_m: 0.3688 - val_precision_m: 0.7273 - val_recall_m: 0.2614
# Epoch 8/50
# 30/30 [==============================] - 23s 766ms/step - loss: 0.7277 - acc: 0.7203 - f1_m: 0.6580 - precision_m: 0.8095 - recall_m: 0.5667 - val_loss: 0.9155 - val_acc: 0.7037 - val_f1_m: 0.4714 - val_precision_m: 0.8909 - val_recall_m: 0.3295
# Epoch 9/50
# 30/30 [==============================] - 24s 780ms/step - loss: 0.7329 - acc: 0.7881 - f1_m: 0.6752 - precision_m: 0.8417 - recall_m: 0.5792 - val_loss: 0.8653 - val_acc: 0.6667 - val_f1_m: 0.4971 - val_precision_m: 0.7242 - val_recall_m: 0.3864
# Epoch 10/50
# %%
# Model training for Xception
# %%time

hist_xception_preprocessed_2 = xception_model_preprocessed_2.fit(train_generator, validation_data=val_generator, epochs=50)
# Guardar modelos en formato H5
xception_model_preprocessed_2.save(os.path.join(save_dir, 'xception_model_preprocessed_2.h5'))
# Out:
# Epoch 1/50
# 30/30 [==============================] - 45s 737ms/step - loss: 2.1366 - acc: 0.2627 - f1_m: 0.2634 - precision_m: 0.3037 - recall_m: 0.2375 - val_loss: 1.4142 - val_acc: 0.2469 - val_f1_m: 0.2431 - val_precision_m: 0.3535 - val_recall_m: 0.1932
# Epoch 2/50
# 30/30 [==============================] - 22s 720ms/step - loss: 1.1381 - acc: 0.5381 - f1_m: 0.4805 - precision_m: 0.6001 - recall_m: 0.4083 - val_loss: 1.2611 - val_acc: 0.3210 - val_f1_m: 0.2685 - val_precision_m: 0.4682 - val_recall_m: 0.1932
# Epoch 3/50
# 30/30 [==============================] - 22s 712ms/step - loss: 0.8612 - acc: 0.6483 - f1_m: 0.6054 - precision_m: 0.7338 - recall_m: 0.5292 - val_loss: 1.1712 - val_acc: 0.4198 - val_f1_m: 0.4083 - val_precision_m: 0.5777 - val_recall_m: 0.3409
# Epoch 4/50
# 30/30 [==============================] - 22s 708ms/step - loss: 0.8177 - acc: 0.6822 - f1_m: 0.6506 - precision_m: 0.7415 - recall_m: 0.5875 - val_loss: 1.2759 - val_acc: 0.4568 - val_f1_m: 0.3765 - val_precision_m: 0.4455 - val_recall_m: 0.3295
# Epoch 5/50
# 30/30 [==============================] - 22s 712ms/step - loss: 0.5848 - acc: 0.7797 - f1_m: 0.7769 - precision_m: 0.8571 - recall_m: 0.7167 - val_loss: 1.2489 - val_acc: 0.4691 - val_f1_m: 0.4369 - val_precision_m: 0.5106 - val_recall_m: 0.3864
# Epoch 6/50
# 30/30 [==============================] - 22s 718ms/step - loss: 0.4752 - acc: 0.8559 - f1_m: 0.8391 - precision_m: 0.9001 - recall_m: 0.7917 - val_loss: 0.8994 - val_acc: 0.6173 - val_f1_m: 0.6047 - val_precision_m: 0.7881 - val_recall_m: 0.5114
# Epoch 7/50
# 30/30 [==============================] - 22s 710ms/step - loss: 0.4142 - acc: 0.8559 - f1_m: 0.8482 - precision_m: 0.8933 - recall_m: 0.8125 - val_loss: 0.8582 - val_acc: 0.6420 - val_f1_m: 0.5944 - val_precision_m: 0.6818 - val_recall_m: 0.5341
# Epoch 8/50
# 30/30 [==============================] - 22s 725ms/step - loss: 0.4045 - acc: 0.8644 - f1_m: 0.8480 - precision_m: 0.8831 - recall_m: 0.8208 - val_loss: 0.7858 - val_acc: 0.6914 - val_f1_m: 0.7167 - val_precision_m: 0.7911 - val_recall_m: 0.6591
# Epoch 9/50
# 30/30 [==============================] - 22s 717ms/step - loss: 0.
Xception, NUM_CLASES, IMG_SIZE[0], IMG_SIZE[1],0.00005,0)

hist_xception_generator_4 = xception_model_generator_4.fit(train_generator_2, validation_data=val_generator_2, epochs=50)
# Out:
# Epoch 1/50
# 30/30 [==============================] - 50s 858ms/step - loss: 1.5833 - acc: 0.3305 - f1_m: 0.1768 - precision_m: 0.3044 - recall_m: 0.1292 - val_loss: 1.4079 - val_acc: 0.1728 - val_f1_m: 0.0000e+00 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# Epoch 2/50
# 30/30 [==============================] - 24s 774ms/step - loss: 1.2900 - acc: 0.4576 - f1_m: 0.3280 - precision_m: 0.5606 - recall_m: 0.2417 - val_loss: 1.3531 - val_acc: 0.2840 - val_f1_m: 0.0000e+00 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# Epoch 3/50
# 30/30 [==============================] - 24s 773ms/step - loss: 1.1113 - acc: 0.5636 - f1_m: 0.4278 - precision_m: 0.6693 - recall_m: 0.3292 - val_loss: 1.2863 - val_acc: 0.3580 - val_f1_m: 0.0000e+00 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# Epoch 4/50
# 30/30 [==============================] - 24s 791ms/step - loss: 1.0838 - acc: 0.5254 - f1_m: 0.4449 - precision_m: 0.6581 - recall_m: 0.3458 - val_loss: 1.2104 - val_acc: 0.4815 - val_f1_m: 0.0404 - val_precision_m: 0.1818 - val_recall_m: 0.0227
# Epoch 5/50
# 30/30 [==============================] - 24s 789ms/step - loss: 0.9376 - acc: 0.6144 - f1_m: 0.5434 - precision_m: 0.7767 - recall_m: 0.4292 - val_loss: 1.1190 - val_acc: 0.5556 - val_f1_m: 0.1758 - val_precision_m: 0.5000 - val_recall_m: 0.1136
# Epoch 6/50
# 30/30 [==============================] - 24s 798ms/step - loss: 0.8016 - acc: 0.7331 - f1_m: 0.6289 - precision_m: 0.7837 - recall_m: 0.5333 - val_loss: 1.0127 - val_acc: 0.7037 - val_f1_m: 0.3352 - val_precision_m: 0.7424 - val_recall_m: 0.2273
# Epoch 7/50
# 30/30 [==============================] - 25s 828ms/step - loss: 0.7854 - acc: 0.7246 - f1_m: 0.6429 - precision_m: 0.8121 - recall_m: 0.5417 - val_loss: 0.8836 - val_acc: 0.7160 - val_f1_m: 0.5044 - val_precision_m: 0.8561 - val_recall_m: 0.3636
# Epoch 8/50
# 30/30 [==============================] - 24s 766ms/step - loss: 0.6777 - acc: 0.7839 - f1_m: 0.6955 - precision_m: 0.8497 - recall_m: 0.6083 - val_loss: 0.8699 - val_acc: 0.7407 - val_f1_m: 0.5117 - val_precision_m: 0.7515 - val_recall_m: 0.3977
# Epoch 9/50
# 30/30 [==============================] - 24s 773ms/step - loss: 0.6732 - acc: 0.7754 - f1_m: 0.7308 - precision_m: 0.8517 - recall_m: 0.6542 - val_loss: 0.7800 - val_acc: 0.7531 - val_f1_m: 0.6615 - val_precision_m: 0.8680 - val_recall_m: 0.5568
# Epoch 10/50
# 30/30 [==============================] - 24s 768ms/step - loss: 0.6643 - acc: 0.7924 - f1_m: 0.7469 - precision_m: 0.8381 - recall_m: 0.6833 - val_loss: 0.6889 - val_acc: 0.7901 - val_f1_m: 0.6776 - val_precision_m: 0.8286 - val_recall_m: 0.5795
# Epoch 11/50
# 30/30 [==============================] - 24s 793ms/step - loss: 0.6100 - acc: 0.7627 - f1_m: 0.7173 - precision_m: 0.8092 - recall_m: 0.6542 - val_loss: 0.6991 - val_acc: 0.7654 - val_f1_m: 0.7458 - val_precision_m: 0.8841 - val_recall_m: 0.6591
# Epoch 12/50
# 30/30 [==============================] - 25s 831ms/step - loss: 0.5424 - acc: 0.8390 - f1_m: 0.8061 - precision_m: 0.8750 - recall_m: 0.7542 - val_loss: 0.6742 - val_acc: 0.7901 - val_f1_m: 0.6461 - val_precision_m: 0.7829 - val_recall_m: 0.5568
# Epoch 13/50
# 30/30 [==============================] - 25s 804ms/step - loss: 0.5726 - acc: 0.8136 - f1_m: 0.7988 - precision_m: 0.8574 - recall_m: 0.7542 - val_loss: 0.6767 - val_acc: 0.7901 - val_f1_m: 0.7543 - val_precision_m: 0.8532 - val_recall_m: 0.6818
# Epoch 14/50
# 30/30 [==============================] - 25s 806ms/step - loss: 0.5076 - acc: 0.8475 - f1_m: 0.8293 - precision_m: 0.9040 - recall_m: 0.7708 - val_loss: 0.5621 - val_acc: 0.8148 - val_f1_m: 0.8342 - val_precision_m: 0.9329 - val_recall_m: 0.7614
# Epoch 15/50
# 30/30 [==============================] - 25s 815ms/step - loss: 0.4892 - acc: 0.8686 - f1_m: 0.8157 - precision_m: 0.8725 - recall_m: 0.7750 - val_loss: 0.5778 - val_acc: 0.8395 - val_f1_m: 0.7297 - val_precision_m: 0.8247 - val_recall_m: 0.6591
# Epoch 16/50
# 30/30 [==============================] - 26s 837ms/step - loss: 0.4226 - acc: 0.8856 - f1_m: 0.8732 - precision_m: 0.9249 - recall_m: 0.8333 - val_loss: 0.5230 - val_acc: 0.8642 - val_f1_m: 0.8223 - val_precision_m: 0.8958 - val_recall_m: 0.7727
# Epoch 17/50
# 30/30 [==============================] - 24s 783ms/step - loss: 0.4492 - acc: 0.8432 - f1_m: 0.8417 - precision_m: 0.9015 - recall_m: 0.8000 - val_loss: 0.5532 - val_acc: 0.7901 - val_f1_m: 0.8016 - val_precision_m: 0.8653 - val_recall_m: 0.7500
# Epoch 18/50
# 30/30 [==============================] - 25s 805ms/step - loss: 0.4396 - acc: 0.8602 - f1_m: 0.8321 - precision_m: 0.9020 - recall_m: 0.7792 - val_loss: 0.5168 - val_acc: 0.8272 - val_f1_m: 0.7937 - val_precision_m: 0.8738 - val_recall_m: 0.7386
# Epoch 19/50
# 30/30 [==============================] - 25s 832ms/step - loss: 0.4397 - acc: 0.8729 - f1_m: 0.8527 - precision_m: 0.9025 - recall_m: 0.8125 - val_loss: 0.5323 - val_acc: 0.8395 - val_f1_m: 0.8386 - val_precision_m: 0.8945 - val_recall_m: 0.7955
# Epoch 20/50
# 30/30 [==============================] - 25s 814ms/step - loss: 0.3703 - acc: 0.8856 - f1_m: 0.8925 - precision_m: 0.9444 - recall_m: 0.8500 - val_loss: 0.4772 - val_acc: 0.8765 - val_f1_m: 0.8559 - val_precision_m: 0.9039 - val_recall_m: 0.8182
# Epoch 21/50
# 30/30 [==============================] - 25s 802ms/step - loss: 0.3953 - acc: 0.8729 - f1_m: 0.8718 - precision_m: 0.9350 - recall_m: 0.8250 - val_loss: 0.4609 - val_acc: 0.8642 - val_f1_m: 0.8756 - val_precision_m: 0.9042 - val_recall_m: 0.8523
# Epoch 22/50
# 30/30 [==============================] - 25s 816ms/step - loss: 0.3033 - acc: 0.9195 - f1_m: 0.9165 - precision_m: 0.9527 - recall_m: 0.8875 - val_loss: 0.4804 - val_acc: 0.8519 - val_f1_m: 0.8527 - val_precision_m: 0.8956 - val_recall_m: 0.8182
# Epoch 23/50
# 30/30 [==============================] - 25s 813ms/step - loss: 0.3131 - acc: 0.9153 - f1_m: 0.9040 - precision_m: 0.9408 - recall_m: 0.8750 - val_loss: 0.4278 - val_acc: 0.8642 - val_f1_m: 0.8755 - val_precision_m: 0.9218 - val_recall_m: 0.8409
# Epoch 24/50
# 30/30 [==============================] - 24s 781ms/step - loss: 0.2770 - acc: 0.9661 - f1_m: 0.9420 - precision_m: 0.9738 - recall_m: 0.9167 - val_loss: 0.4337 - val_acc: 0.8519 - val_f1_m: 0.8915 - val_precision_m: 0.9248 - val_recall_m: 0.8636
# Epoch 25/50
# 30/30 [==============================] - 25s 833ms/step - loss: 0.2659 - acc: 0.9534 - f1_m: 0.9289 - precision_m: 0.9599 - recall_m: 0.9042 - val_loss: 0.4817 - val_acc: 0.8148 - val_f1_m: 0.8273 - val_precision_m: 0.8377 - val_recall_m: 0.8182
# Epoch 26/50
# 30/30 [==============================] - 25s 820ms/step - loss: 0.3132 - acc: 0.9110 - f1_m: 0.9004 - precision_m: 0.9300 - recall_m: 0.8750 - val_loss: 0.4159 - val_acc: 0.8519 - val_f1_m: 0.7832 - val_precision_m: 0.8231 - val_recall_m: 0.7500
# Epoch 27/50
# 30/30 [==============================] - 24s 788ms/step - loss: 0.2735 - acc: 0.9322 - f1_m: 0.9290 - precision_m: 0.9488 - recall_m: 0.9125 - val_loss: 0.4484 - val_acc: 0.8765 - val_f1_m: 0.8650 - val_precision_m: 0.8945 - val_recall_m: 0.8409
# Epoch 28/50
# 30/30 [==============================] - 24s 789ms/step - loss: 0.2438 - acc: 0.9280 - f1_m: 0.9333 - precision_m: 0.9482 - recall_m: 0.9208 - val_loss: 0.4467 - val_acc: 0.8272 - val_f1_m: 0.8582 - val_precision_m: 0.8929 - val_recall_m: 0.8295
# Epoch 29/50
# 30/30 [==============================] - 26s 836ms/step - loss: 0.2567 - acc: 0.9364 - f1_m: 0.9277 - precision_m: 0.9454 - recall_m: 0.9125 - val_loss: 0.4260 - val_acc: 0.8519 - val_f1_m: 0.8718 - val_precision_m: 0.8826 - val_recall_m: 0.8636
# Epoch 30/50
# 30/30 [==============================] - 25s 801ms/step - loss: 0.2622 - acc: 0.9492 - f1_m: 0.9447 - precision_m: 0.9530 - recall_m: 0.9375 - val_loss: 0.4474 - val_acc: 0.8519 - val_f1_m: 0.8538 - val_precision_m: 0.8685 - val_recall_m: 0.8409
# Epoch 31/50
# 30/30 [==============================] - 25s 814ms/step - loss: 0.1812 - acc: 0.9661 - f1_m: 0.9647 - precision_m: 0.9821 - recall_m: 0.9500 - val_loss: 0.4401 - val_acc: 0.8519 - val_f1_m: 0.8736 - val_precision_m: 0.9286 - val_recall_m: 0.8295
# Epoch 32/50
# 30/30 [==============================] - 24s 795ms/step - loss: 0.2508 - acc: 0.9237 - f1_m: 0.9227 - precision_m: 0.9399 - recall_m: 0.9083 - val_loss: 0.4041 - val_acc: 0.8765 - val_f1_m: 0.8995 - val_precision_m: 0.9583 - val_recall_m: 0.8523
# Epoch 33/50
# 30/30 [==============================] - 25s 800ms/step - loss: 0.2412 - acc: 0.9280 - f1_m: 0.9213 - precision_m: 0.9365 - recall_m: 0.9083 - val_loss: 0.3755 - val_acc: 0.9012 - val_f1_m: 0.9105 - val_precision_m: 0.9399 - val_recall_m: 0.8864
# Epoch 34/50
# 30/30 [==============================] - 25s 816ms/step - loss: 0.2251 - acc: 0.9492 - f1_m: 0.9410 - precision_m: 0.9661 - recall_m: 0.9208 - val_loss: 0.4169 - val_acc: 0.8519 - val_f1_m: 0.8712 - val_precision_m: 0.8929 - val_recall_m: 0.8523
# Epoch 35/50
# 30/30 [==============================] - 25s 803ms/step - loss: 0.2629 - acc: 0.9364 - f1_m: 0.9136 - precision_m: 0.9292 - recall_m: 0.9000 - val_loss: 0.4364 - val_acc: 0.8519 - val_f1_m: 0.8663 - val_precision_m: 0.9118 - val_recall_m: 0.8295
# Epoch 36/50
# 30/30 [==============================] - 25s 835ms/step - loss: 0.1677 - acc: 0.9746 - f1_m: 0.9656 - precision_m: 0.9786 - recall_m: 0.9542 - val_loss: 0.4469 - val_acc: 0.8272 - val_f1_m: 0.8310 - val_precision_m: 0.8658 - val_recall_m: 0.8068
# Epoch 37/50
# 30/30 [==============================] - 25s 810ms/step - loss: 0.1992 - acc: 0.9492 - f1_m: 0.9447 - precision_m: 0.9583 - recall_m: 0.9333 - val_loss: 0.4284 - val_acc: 0.8642 - val_f1_m: 0.8693 - val_precision_m: 0.9048 - val_recall_m: 0.8409
# Epoch 38/50
# 30/30 [==============================] - 24s 800ms/step - loss: 0.2285 - acc: 0.9364 - f1_m: 0.9304 - precision_m: 0.9522 - recall_m: 0.9125 - val_loss: 0.3876 - val_acc: 0.8519 - val_f1_m: 0.8771 - val_precision_m: 0.8939 - val_recall_m: 0.8636
# Epoch 39/50
# 30/30 [==============================] - 24s 788ms/step - loss: 0.1911 - acc: 0.9576 - f1_m: 0.9521 - precision_m: 0.9647 - recall_m: 0.9417 - val_loss: 0.3884 - val_acc: 0.8519 - val_f1_m: 0.8674 - val_precision_m: 0.8847 - val_recall_m: 0.8523
# Epoch 40/50
# 30/30 [==============================] - 25s 804ms/step - loss: 0.1622 - acc: 0.9576 - f1_m: 0.9423 - precision_m: 0.9480 - recall_m: 0.9375 - val_loss: 0.4994 - val_acc: 0.8395 - val_f1_m: 0.8432 - val_precision_m: 0.8588 - val_recall_m: 0.8295
# Epoch 41/50
# 30/30 [==============================] - 25s 807ms/step - loss: 0.1809 - acc: 0.9449 - f1_m: 0.9435 - precision_m: 0.9611 - recall_m: 0.9292 - val_loss: 0.3915 - val_acc: 0.9012 - val_f1_m: 0.8264 - val_precision_m: 0.8506 - val_recall_m: 0.8068
# Epoch 42/50
# 30/30 [==============================] - 24s 792ms/step - loss: 0.2068 - acc: 0.9407 - f1_m: 0.9332 - precision_m: 0.9486 - recall_m: 0.9208 - val_loss: 0.3461 - val_acc: 0.8765 - val_f1_m: 0.8916 - val_precision_m: 0.9253 - val_recall_m: 0.8636
# Epoch 43/50
# 30/30 [==============================] - 24s 784ms/step - loss: 0.2480 - acc: 0.9364 - f1_m: 0.9305 - precision_m: 0.9470 - recall_m: 0.9167 - val_loss: 0.3480 - val_acc: 0.9012 - val_f1_m: 0.8962 - val_precision_m: 0.9075 - val_recall_m: 0.8864
# Epoch 44/50
# 30/30 [==============================] - 24s 787ms/step - loss: 0.1340 - acc: 0.9831 - f1_m: 0.9831 - precision_m: 0.9875 - recall_m: 0.9792 - val_loss: 0.3827 - val_acc: 0.8765 - val_f1_m: 0.8702 - val_precision_m: 0.9075 - val_recall_m: 0.8409
# Epoch 45/50
# 30/30 [==============================] - 25s 824ms/step - loss: 0.1420 - acc: 0.9619 - f1_m: 0.9566 - precision_m: 0.9744 - recall_m: 0.9417 - val_loss: 0.3861 - val_acc: 0.8889 - val_f1_m: 0.8962 - val_precision_m: 0.9075 - val_recall_m: 0.8864
# Epoch 46/50
# 30/30 [==============================] - 24s 789ms/step - loss: 0.2381 - acc: 0.9364 - f1_m: 0.9425 - precision_m: 0.9530 - recall_m: 0.9333 - val_loss: 0.4309 - val_acc: 0.8272 - val_f1_m: 0.8415 - val_precision_m: 0.8566 - val_recall_m: 0.8295
# Epoch 47/50
# 30/30 [==============================] - 24s 790ms/step - loss: 0.1669 - acc: 0.9703 - f1_m: 0.9621 - precision_m: 0.9821 - recall_m: 0.9458 - val_loss: 0.3789 - val_acc: 0.9012 - val_f1_m: 0.8341 - val_precision_m: 0.8393 - val_recall_m: 0.8295
# Epoch 48/50
# 30/30 [==============================] - 24s 800ms/step - loss: 0.1358 - acc: 0.9661 - f1_m: 0.9667 - precision_m: 0.9667 - recall_m: 0.9667 - val_loss: 0.3531 - val_acc: 0.8889 - val_f1_m: 0.9051 - val_precision_m: 0.9280 - val_recall_m: 0.8864
# Epoch 49/50
# 30/30 [==============================] - 24s 777ms/step - loss: 0.1596 - acc: 0.9661 - f1_m: 0.9633 - precision_m: 0.9744 - recall_m: 0.9542 - val_loss: 0.3475 - val_acc: 0.9012 - val_f1_m: 0.9053 - val_precision_m: 0.9269 - val_recall_m: 0.8864
# Epoch 50/50
# 30/30 [==============================] - 24s 776ms/step - loss: 0.1630 - acc: 0.9703 - f1_m: 0.9528 - precision_m: 0.9607 - recall_m: 0.9458 - val_loss: 0.3686 - val_acc: 0.8889 - val_f1_m: 0.9061 - val_precision_m: 0.9286 - val_recall_m: 0.8864

# %% [markdown]
# # Evaluacion de modelos

# %% [markdown]
# # validacion de resultados

# %%
from tensorflow.keras.models import load_model
import os

save_dir = '/content/drive/My Drive/SavedModels'


xception_model_preprocessed.save(os.path.join(save_dir, 'final_xception_model_10.h5'))
xception_model_preprocessed_2.save(os.path.join(save_dir, 'final_xception_model_2.h5'))
xception_model_generator_2.save(os.path.join(save_dir, 'final_xception_model_v3.h5'))

# %%
# Evaluación en el conjunto de prueba
test_gen = ImageDataGenerator(rescale=1/255.)
test_generator = test_gen.flow_from_directory(directory=test_dir, target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode='categorical')
# Out:
# Found 83 images belonging to 4 classes.

# %%
import pandas as pd
from sklearn.metrics import classification_report
from tabulate import tabulate

def evaluate_and_print_metrics(model, model_name, test_generator):
    # Evaluación en el conjunto de prueba
    evaluation = model.evaluate(test_generator)

    # Obtener las predicciones para calcular otras métricas
    predictions = model.predict(test_generator)

    # Calcular métricas adicionales usando classification_report de scikit-learn
    report = classification_report(test_generator.classes, predictions.argmax(axis=1), target_names=test_generator.class_indices)

    # Obtener las métricas de precisión para cada modelo
    precision = evaluation[1]  # Extraer las métricas de interés
    f1 = float(report.split()[-2])
    recall = float(report.split()[-4])

    # Crear un DataFrame con las métricas
    df = pd.DataFrame({
        'Modelo': [model_name],
        'Precisión': [precision],
        'Recall': [recall],
        'F1': [f1]
        # Puedes agregar otras métricas si es necesario
    })

    # Muestra el DataFrame
    print(df)

    # Mostrar la tabla
    print(tabulate(df, headers='keys', tablefmt='pretty', showindex=False))

    return df

# %%
result_df = evaluate_and_print_metrics(xception_model_preprocessed, 'xception_model_v1', test_generator)
# Out:
# 11/11 [==============================] - 41s 4s/step - loss: 0.4314 - acc: 0.8072 - f1_m: 0.8045 - precision_m: 0.8106 - recall_m: 0.7992
# 11/11 [==============================] - 3s 233ms/step
#               Modelo  Precisión  Recall    F1
# 0  xception_model_v1   0.807229    0.27  0.27
# +-------------------+--------------------+--------+------+
# |      Modelo       |     Precisión      | Recall |  F1  |
# +-------------------+--------------------+--------+------+
# | xception_model_v1 | 0.8072289228439331 |  0.27  | 0.27 |
# +-------------------+--------------------+--------+------+

# %%
result_df = evaluate_and_print_metrics(xception_model_preprocessed_2, 'xception_model_v2', test_generator)
# Out:
# 11/11 [==============================] - 3s 206ms/step - loss: 0.4527 - acc: 0.8193 - f1_m: 0.8273 - precision_m: 0.8377 - recall_m: 0.8182
# 11/11 [==============================] - 3s 219ms/step
#               Modelo  Precisión  Recall    F1
# 0  xception_model_vv   0.819277    0.18  0.17
# +-------------------+--------------------+--------+------+
# |      Modelo       |     Precisión      | Recall |  F1  |
# +-------------------+--------------------+--------+------+
# | xception_model_vv | 0.8192771077156067 |  0.18  | 0.17 |
# +-------------------+--------------------+--------+------+

# %%
result_df = evaluate_and_print_metrics(xception_model_generator_2, 'xception_model_v3', test_generator)
# Out:
# 11/11 [==============================] - 3s 228ms/step - loss: 0.4571 - acc: 0.8675 - f1_m: 0.8553 - precision_m: 0.8674 - recall_m: 0.8447
# 11/11 [==============================] - 3s 232ms/step
#               Modelo  Precisión  Recall    F1
# 0  xception_model_v3    0.86747    0.26  0.26
# +-------------------+--------------------+--------+------+
# |      Modelo       |     Precisión      | Recall |  F1  |
# +-------------------+--------------------+--------+------+
# | xception_model_v3 | 0.8674699068069458 |  0.26  | 0.26 |
# +-------------------+--------------------+--------+------+

# %%
result_df = evaluate_and_print_metrics(xception_model_generator_4, 'xception_model_v2', test_generator)
# Out:
# 11/11 [==============================] - 3s 236ms/step - loss: 0.3618 - acc: 0.8554 - f1_m: 0.8574 - precision_m: 0.9037 - recall_m: 0.8182
# 11/11 [==============================] - 4s 238ms/step
#               Modelo  Precisión  Recall    F1
# 0  xception_model_v2   0.855422    0.22  0.22
# +-------------------+--------------------+--------+------+
# |      Modelo       |     Precisión      | Recall |  F1  |
# +-------------------+--------------------+--------+------+
# | xception_model_v2 | 0.8554216623306274 |  0.22  | 0.22 |
# +-------------------+--------------------+--------+------+

# %%
import matplotlib.pyplot as plt

def plot_hist(hist):
    # Crear la figura y los ejes
    fig, ax = plt.subplots(figsize=(10, 6))

    # Plotear accuracy y val_accuracy
    ax.plot(hist.history["acc"], label="Train Accuracy", color="blue", linestyle="-")
    ax.plot(hist.history["val_acc"], label="Validation Accuracy", color="blue", linestyle="--")

    # Plotear precision_m y val_precision_m
    ax.plot(hist.history["precision_m"], label="Train Precision", color="green", linestyle="-")
    ax.plot(hist.history["val_precision_m"], label="Validation Precision", color="green", linestyle="--")

    # Configurar el subplot
    ax.set_title("Model Metrics")
    ax.set_ylabel("Metrics")
    ax.set_xlabel("Epoch")
    ax.legend(loc="upper left")

    # Mostrar la gráfica
    plt.show()

# Ejemplo de uso:
# Suponiendo que `hist` es el objeto devuelto por el entrenamiento del modelo
# model.fit(...)
# plot_hist(hist)

# %%
import matplotlib.pyplot as plt

def plot_metrics_loss_f1(history, name):
    fig, ax = plt.subplots(figsize=(10, 6))
    fig.suptitle('Model Metrics Comparison', fontsize=16)

    # Pérdida
    ax.plot(history.history['loss'], label='Train Loss', color='blue', linestyle='-')
    ax.plot(history.history['val_loss'], label='Validation Loss', color='blue', linestyle='--')

    # F1 Score
    ax.plot(history.history['f1_m'], label='Train F1 Score', color='orange', linestyle='-')
    ax.plot(history.history['val_f1_m'], label='Validation F1 Score', color='orange', linestyle='--')

    ax.set_title(name)
    ax.set_xlabel('Epoch')
    ax.set_ylabel('Metrics')
    ax.legend()

    plt.show()

# Ejemplo de uso:
# Suponiendo que `history` y `name` son los datos proporcionados para un solo modelo
# plot_metrics_loss_f1(history, name)

# %%
import matplotlib.pyplot as plt

def plot_hist(hist):
    # Crear la figura y los ejes
    fig, ax = plt.subplots(figsize=(10, 6))

    # Plotear accuracy y val_accuracy
    ax.plot(hist.history["acc"], label="Train Accuracy", color="blue", linestyle="-")
    ax.plot(hist.history["val_acc"], label="Validation Accuracy", color="blue", linestyle="--")

    # Plotear precision_m y val_precision_m
    ax.plot(hist.history["precision_m"], label="Train Precision", color="green", linestyle="-")
    ax.plot(hist.history["val_precision_m"], label="Validation Precision", color="green", linestyle="--")

    # Configurar el subplot
    ax.set_title("Model Metrics")
    ax.set_ylabel("Metrics")
    ax.set_xlabel("Epoch")
    ax.legend(loc="upper left")

    # Mostrar la gráfica
    plt.show()

# Ejemplo de uso:
# Suponiendo que `hist` es el objeto devuelto por el entrenamiento del modelo
# model.fit(...)
# plot_hist(hist)

# %%
modelos = ['Xception_10']


historias = [
   hist_xception_preprocessed
]
nombres = [
    'Xception (10 capas congeladas)',
]

# %%
plot_hist(hist_xception_preprocessed)

# %%
plot_metrics_loss_f1(hist_xception_preprocessed,'hist_xception_preprocessed')

# %%
nombres
