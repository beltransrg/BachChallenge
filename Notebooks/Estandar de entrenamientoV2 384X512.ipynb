# %% [markdown]
# #  Imports

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Flatten, Activation, Dropout, MaxPooling2D, BatchNormalization, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Precision, Recall, AUC
from tensorflow.keras.applications import Xception, EfficientNetB0
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix, accuracy_score

from sklearn.metrics import f1_score


import seaborn as sns
import matplotlib.pyplot as plt
import os

# %% [markdown]
# # Function Definitions

# %%
def train_val_generators(train_dir, val_dir):
    train_gen = ImageDataGenerator(rescale=1/255., horizontal_flip=True, vertical_flip=True, zoom_range=0.2)
    train_generator = train_gen.flow_from_directory(directory=train_dir, target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode='categorical')

    val_gen = ImageDataGenerator(rescale=1/255.)
    val_generator = val_gen.flow_from_directory(directory=val_dir, target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode='categorical')

    return train_generator, val_generator


def train_model(model, train_generator, val_generator, epochs=15):
    callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)

    history = model.fit(train_generator, validation_data=val_generator, epochs=epochs, callbacks=[callback])

    return history

# %%
def assign_labels(test_generator, model, print_info=True):
    test_labels = []
    pred_labels = []

    for batch in range(0, int(len(test_generator))):
        batch_predicted = model.predict(test_generator[batch][0])
        for i in range(len(batch_predicted)):
            pred_label = np.argmax(batch_predicted[i])
            true_label = np.argmax(test_generator[batch][1][i])
            true_name = bc_types[true_label]  # Decode true label to category
            pred_name = bc_types[pred_label]  # Decode predicted label to category
            true_category = dict_bc[bc_dict[true_name]]  # Use bc_dict to get the value and then access dict_bc
            pred_category = dict_bc[bc_dict[pred_name]]  # Use bc_dict to get the value and then access dict_bc

            pred_labels.append(pred_category)
            test_labels.append(true_category)

            if print_info:
                print(f"Imagen {batch * len(batch_predicted) + i + 1} - Verdadero: {true_category} ( {true_name} ), Predicho: {pred_category} ( {pred_name} )")

    return test_labels, pred_labels

# %%
import seaborn as sns
import matplotlib.pyplot as plt

import seaborn as sns
import matplotlib.pyplot as plt

def plot_training_history(history):
    # Plotear el historial de entrenamiento
    eps = range(len(history.history["loss"]))
    plt.figure(figsize=(10, 6))
    plt.plot(eps, history.history["loss"])
    plt.plot(eps, history.history["val_loss"])
    plt.legend(["loss", "val_loss"])
    plt.title('Training History - Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.show()

    # Plotear la precisión
    plt.figure(figsize=(10, 6))
    plt.plot(eps, history.history["accuracy"])
    plt.plot(eps, history.history["val_accuracy"])
    plt.legend(["accuracy", "val_accuracy"])
    plt.title('Training History - Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.show()

def check_precision(model, test_generator):
    # Asignar e imprimir etiquetas
    test_labels, pred_labels = assign_labels(test_generator, model, print_info=False)

    # Imprimir la matriz de confusión y la precisión
    cm = confusion_matrix(test_labels, pred_labels)
    accuracy = accuracy_score(test_labels, pred_labels)

    print("Matriz de Confusión:")
    print(cm)
    print("Precisión:", accuracy)
    return cm

# %%
def plot_confusion_matrix(cm, classes):
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', xticklabels=classes, yticklabels=classes)
    plt.title('Matriz de Confusión')
    plt.xlabel('Etiquetas Predichas')
    plt.ylabel('Etiquetas Verdaderas')
    plt.show()

# %% [markdown]
# # Configuracion inicial

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Directorio base después de montar el drive
base_path = '/content/drive/My Drive/DataSet'

# Listar archivos en el directorio base
files = os.listdir(base_path)

path_root = '/content/drive/My Drive/DataSet'

valid_dir = os.path.join(path_root, 'val')
train_dir = os.path.join(path_root, 'train')
test_dir = os.path.join(path_root, 'test')

# %%
bc_types = [file for file in os.listdir(train_dir) if os.path.isdir(os.path.join(train_dir, file))]
print("Types: ", bc_types)

# to encode labels
bc_dict = {'InSitu': 3, 'Benign': 2, 'Normal': 1, 'Invasive': 4}
print("Encode: ", bc_dict)

# to decode labels
dict_bc = {1: "Normal", 2: "Benign", 3: "InSitu", 4: "Invasive"}
print("Decode: ", dict_bc)

classes = [dict_bc[i] for i in sorted(dict_bc.keys())]
# Out:
# Types:  ['InSitu', 'Normal', 'Invasive', 'Benign']
# Encode:  {'InSitu': 3, 'Benign': 2, 'Normal': 1, 'Invasive': 4}
# Decode:  {1: 'Normal', 2: 'Benign', 3: 'InSitu', 4: 'Invasive'}

# %%
# Set IMG_SIZE and BATCH_SIZE
IMG_SIZE = (384,512)

BATCH_SIZE = 16
NUM_CLASES = 4

# %%
import imghdr  # Importar el módulo imghdr para verificar el tipo de imagen

# Calcular el rango de píxeles en lugar de asumir que es 255
pixel_min = float('inf')  # Inicializar con un valor grande
pixel_max = float('-inf')  # Inicializar con un valor pequeño

# Iterar sobre las imágenes en el conjunto de entrenamiento para encontrar el rango real
for root, dirs, files in os.walk(train_dir):
    for file in files:
        img_path = os.path.join(root, file)

        # Verificar si el archivo es una imagen
        if imghdr.what(img_path) is not None:
            img = plt.imread(img_path)
            img_min = np.min(img)
            img_max = np.max(img)
            pixel_min = min(pixel_min, img_min)
            pixel_max = max(pixel_max, img_max)

# %%
pixel_min
# Out:
# 0

# %%
train_generator, val_generator = train_val_generators(train_dir, valid_dir)   # create image generators to feed images to the model
# Out:
# Found 236 images belonging to 4 classes.
# Found 81 images belonging to 4 classes.

# %% [markdown]
# # Create models

# %%
#Para poder incluir el valor f1 en el entrenamiento del modelo creamos las siguientes
#funciones para añadirlo como una función siguiendo la referencia del sigueinte enlace
#https://datascience.stackexchange.com/questions/45165/how-to-get-accuracy-f1-precision-and-recall-for-a-keras-model

from keras import backend as K
def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %% [markdown]
# ## Xcepcion

# %%
def create_model_Xception(base_model, learning_rate, optimizer='adamax'):
    # Function for creating an Xception-based model with specific architecture and settings
    METRICS = [
        'accuracy',
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall'),
        tf.keras.metrics.AUC(name='AUC'),
    ]

    model = Sequential([
        base_model,
        Conv2D(32, (3, 3), activation="relu"),
        BatchNormalization(),
        MaxPooling2D(2, 2),
        Dropout(0.3),
        Flatten(),
        Dense(64, activation="relu"),
        Dense(4, activation="softmax"),
    ])
    model.compile(optimizer=optimizer, loss="categorical_crossentropy", metrics=['acc',f1_m,precision_m, recall_m])

    return model

# %%
def create_model_Xception_unfreeze(base_model, learning_rate, optimizer='adamax'):
    # Function for creating an Xception-based model with specific architecture and settings
    METRICS = [
        'accuracy',
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall'),
        tf.keras.metrics.AUC(name='AUC'),
    ]

# Congelar capas preentrenadas
    for layer in base_model.layers:
        layer.trainable = False

    model = Sequential([
        base_model,
        Conv2D(32, (3, 3), activation="relu"),
        BatchNormalization(),
        MaxPooling2D(2, 2),
        Dropout(0.3),
        Flatten(),
        Dense(64, activation="relu"),
        Dense(4, activation="softmax"),
    ])
    model.compile(optimizer=optimizer, loss="categorical_crossentropy", metrics=['acc',f1_m,precision_m, recall_m])

    return model

# %%
xception_base_model = tf.keras.applications.Xception(input_shape=(IMG_SIZE[0], IMG_SIZE[1], 3), include_top=False)

xception_model = create_model_Xception(xception_base_model,0.001)
xception_model_lr2 = create_model_Xception(xception_base_model,0.0001)

# %%
# Mostrar información sobre las capas
for i, layer in enumerate(xception_model.layers):
    print(f"Capa {i + 1}: {layer.name}")
    print(f"  - Dimensión de Entrada: {layer.input_shape}")
    print(f"  - Dimensión de Salida: {layer.output_shape}")
    print("=" * 40)

# %%
xception_model_unfreeze = create_model_Xception_unfreeze(xception_base_model,0.001)

# %% [markdown]
# ## ResNet

# %% [markdown]
# # EfficientB0

# %%
from tensorflow.keras import layers
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications import EfficientNetB0

def create_model_efficientnetb0(num_classes, img_size1, img_size2):
    inputs = layers.Input(shape=(img_size1, img_size2, 3))

    # EfficientNetB0 como modelo base
    base_model = EfficientNetB0(include_top=False, input_tensor=inputs, weights="imagenet")
    base_model.trainable = False

    model = Sequential([
        base_model,
        layers.GlobalAveragePooling2D(name="avg_pool"),
        layers.BatchNormalization(),
        layers.Dropout(0.2, name="top_dropout"),
        layers.Dense(num_classes, activation="softmax", name="pred"),
    ], name="CustomEfficientNetB0")

    optimizer = Adam(learning_rate=0.0002)
    model.compile(optimizer=optimizer, loss="categorical_crossentropy", metrics=['acc', f1_m, precision_m, recall_m])

    return model

# %%
model_EfficientNetB0_1 = create_model_efficientnetb0(4, IMG_SIZE[0], IMG_SIZE[1])
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 [==============================] - 0s 0us/step

# %%
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.optimizers import RMSprop

def build_model_V3(num_classes,img_size1,img_size2):
    inputs = layers.Input(shape=(img_size1,img_size2, 3))
    #x = img_augmentation(inputs)
    x = inputs
    model = InceptionV3(weights='imagenet',input_tensor=x,include_top=False,input_shape=(img_size1,img_size2,3))

    # Freeze the pretrained weights
    model.trainable = False

    # Rebuild top
    x = layers.GlobalAveragePooling2D(name="avg_pool")(model.output)
    x = layers.BatchNormalization()(x)

    top_dropout_rate = 0.2
    x = layers.Dropout(top_dropout_rate, name="top_dropout")(x)
    outputs = layers.Dense(4, activation="softmax", name="pred")(x)

    # Compile
    model = tf.keras.Model(inputs, outputs, name="V3")
    optimizer = tf.keras.optimizers.Adam(learning_rate=0.0002)
    #optimizer = tf.keras.optimizers.Adam(learning_rate=0.01)

    model.compile(
        optimizer=optimizer, loss="categorical_crossentropy", metrics=['acc',f1_m,precision_m, recall_m]
    )
    return model

# %%
model_V3 = build_model_V3(4,IMG_SIZE[0], IMG_SIZE[1])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 45s 1us/step

# %% [markdown]
# ## VGG

# %%
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

def build_model_VGG16(input_shape1, input_shape2, num_classes=4):
    # Cargar el modelo VGG16 preentrenado sin la capa densa superior (include_top=False)
    base_model = VGG16(include_top=False, weights="imagenet", input_shape=(input_shape1, input_shape2, 3))

    # Congelar las capas convolucionales preentrenadas
    for layer in base_model.layers:
        layer.trainable = False

    # Agregar capas personalizadas para la clasificación
    x = GlobalAveragePooling2D()(base_model.output)
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.5)(x)
    predictions = Dense(num_classes, activation='softmax')(x)

    # Crear el modelo personalizado
    custom_model = Model(inputs=base_model.input, outputs=predictions)

    # Compilar el modelo con el optimizador Adam y pérdida categórica entropía cruzada
    custom_model.compile(optimizer=Adam(learning_rate=0.0002),
                        loss='categorical_crossentropy',
                        metrics=['acc',f1_m,precision_m, recall_m])

    return custom_model

# %%
model_vgg16 = build_model_VGG16(IMG_SIZE[0], IMG_SIZE[1],4)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step

# %%
from tensorflow.keras.applications import VGG19
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

def build_model_VGG19(input_shape1, input_shape2, num_classes=4):
    # Cargar el modelo VGG19 preentrenado sin la capa densa superior (include_top=False)
    base_model = VGG19(include_top=False, weights="imagenet", input_shape=(input_shape1, input_shape2, 3))

    # Congelar las capas convolucionales preentrenadas
    for layer in base_model.layers:
        layer.trainable = False

    # Agregar capas personalizadas para la clasificación
    x = GlobalAveragePooling2D()(base_model.output)
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.5)(x)
    predictions = Dense(num_classes, activation='softmax')(x)

    # Crear el modelo personalizado
    custom_model = Model(inputs=base_model.input, outputs=predictions)

    # Compilar el modelo con el optimizador Adam y pérdida categórica entropía cruzada
    custom_model.compile(optimizer=Adam(learning_rate=0.0002),
                        loss='categorical_crossentropy',
                        metrics=['acc',f1_m,precision_m, recall_m])

    return custom_model

# %%
model_vgg19 = build_model_VGG19(IMG_SIZE[0], IMG_SIZE[1],4)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 1s 0us/step

# %% [markdown]
# ## resnet

# %%
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

def build_model_resnet(input_shape1, input_shape2, num_classes=4):
    # Cargar el modelo ResNet50 preentrenado sin la capa densa superior (include_top=False)
    base_model = ResNet50(include_top=False, weights="imagenet", input_shape=(input_shape1, input_shape2, 3))


    # Agregar capas personalizadas para la clasificación
    x = GlobalAveragePooling2D()(base_model.output)
    x = Dense(512, activation='relu')(x)
    x = Dropout(0.5)(x)
    predictions = Dense(num_classes, activation='softmax')(x)

    # Crear el modelo personalizado
    custom_model = Model(inputs=base_model.input, outputs=predictions)

    # Compilar el modelo con el optimizador Adam y pérdida categórica entropía cruzada
    custom_model.compile(optimizer=Adam(learning_rate=0.0002),
                        loss='categorical_crossentropy',
                        metrics=['acc',f1_m,precision_m, recall_m])

    return custom_model

# %%
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

def build_model_resnet2(input_shape1, input_shape2, num_classes=4):
    # Cargar el modelo ResNet50 preentrenado sin la capa densa superior (include_top=False)
    base_model = ResNet50(include_top=False, weights="imagenet", input_shape=(input_shape1, input_shape2, 3))


    # Agregar capas personalizadas para la clasificación
    x = GlobalAveragePooling2D()(base_model.output)
    x = Flatten()(x)  # Aplanar los datos si la salida de GlobalAveragePooling2D es rectangular
    x = Dropout(0.5)(x)
    predictions = Dense(num_classes, activation='softmax')(x)

    # Crear el modelo personalizado
    custom_model = Model(inputs=base_model.input, outputs=predictions)

    # Compilar el modelo con el optimizador Adam y pérdida categórica entropía cruzada
    custom_model.compile(optimizer=Adam(learning_rate=0.0002),
                        loss='categorical_crossentropy',
                        metrics=['acc',f1_m,precision_m, recall_m])

    return custom_model

# %%
IMG_SIZE
# Out:
# (384, 512)

# %%
model_resnet = build_model_resnet(IMG_SIZE[0], IMG_SIZE[1],4)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 0s 0us/step

# %%
model_resnet2 = build_model_resnet2(IMG_SIZE[0], IMG_SIZE[1],4)

# %%
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.optimizers import RMSprop

def build_model_V3(num_classes,img_size1,img_size2):
    inputs = layers.Input(shape=(img_size1,img_size2, 3))
    #x = img_augmentation(inputs)
    x = inputs
    model = InceptionV3(weights='imagenet',input_tensor=x,include_top=False,input_shape=(img_size1,img_size2,3))

    # Freeze the pretrained weights
    model.trainable = False

    # Rebuild top
    x = layers.GlobalAveragePooling2D(name="avg_pool")(model.output)
    x = layers.BatchNormalization()(x)

    top_dropout_rate = 0.2
    x = layers.Dropout(top_dropout_rate, name="top_dropout")(x)
    outputs = layers.Dense(4, activation="softmax", name="pred")(x)

    # Compile
    model = tf.keras.Model(inputs, outputs, name="V3")
    optimizer = tf.keras.optimizers.Adam(learning_rate=0.0002)
    #optimizer = tf.keras.optimizers.Adam(learning_rate=0.01)

    model.compile(
        optimizer=optimizer, loss="categorical_crossentropy", metrics=['acc',f1_m,precision_m, recall_m]
    )
    return model

# %% [markdown]
# # Entrenamiento de modelos

# %%
train_gen, val_gen = train_val_generators(train_dir, valid_dir)
# Out:
# Found 236 images belonging to 4 classes.
# Found 81 images belonging to 4 classes.

# %%
callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)   # limitation to stop somewhere early

# %%
# %%time

print("\n[INFO] Ready to train. Training is starting!\n")
BATCH_SIZE = 8
train_gen, val_gen = train_val_generators(train_dir, valid_dir)   # create image generators to feed images to the model

hist_xception = xception_model.fit(train_gen, validation_data=val_gen, epochs=25, callbacks=[callback])
# Out:
# [INFO] Ready to train. Training is starting!
#
# Found 236 images belonging to 4 classes.
# Found 81 images belonging to 4 classes.
# Epoch 1/25
# 30/30 [==============================] - 96s 2s/step - loss: 1.7340 - acc: 0.3814 - f1_m: 0.3242 - precision_m: 0.3823 - recall_m: 0.2875 - val_loss: 2.3248 - val_acc: 0.2469 - val_f1_m: 0.2275 - val_precision_m: 0.2597 - val_recall_m: 0.2045
# Epoch 2/25
# 30/30 [==============================] - 18s 591ms/step - loss: 1.2158 - acc: 0.4958 - f1_m: 0.4555 - precision_m: 0.5448 - recall_m: 0.4042 - val_loss: 1.6665 - val_acc: 0.3580 - val_f1_m: 0.2537 - val_precision_m: 0.3970 - val_recall_m: 0.1932
# Epoch 3/25
# 30/30 [==============================] - 18s 596ms/step - loss: 0.9948 - acc: 0.6102 - f1_m: 0.5953 - precision_m: 0.6947 - recall_m: 0.5292 - val_loss: 1.4611 - val_acc: 0.4444 - val_f1_m: 0.4298 - val_precision_m: 0.5848 - val_recall_m: 0.3636
# Epoch 4/25
# 30/30 [==============================] - 19s 612ms/step - loss: 0.7005 - acc: 0.7331 - f1_m: 0.7071 - precision_m: 0.7711 - recall_m: 0.6583 - val_loss: 1.1797 - val_acc: 0.5185 - val_f1_m: 0.3985 - val_precision_m: 0.5377 - val_recall_m: 0.3295
# Epoch 5/25
# 30/30 [==============================] - 19s 618ms/step - loss: 0.7956 - acc: 0.6992 - f1_m: 0.6875 - precision_m: 0.7355 - recall_m: 0.6500 - val_loss: 1.1655 - val_acc: 0.5432 - val_f1_m: 0.4555 - val_precision_m: 0.5189 - val_recall_m: 0.4091
# Epoch 6/25
# 30/30 [==============================] - 19s 606ms/step - loss: 0.6284 - acc: 0.7415 - f1_m: 0.7549 - precision_m: 0.7989 - recall_m: 0.7208 - val_loss: 0.8610 - val_acc: 0.6790 - val_f1_m: 0.5872 - val_precision_m: 0.7075 - val_recall_m: 0.5114
# Epoch 7/25
# 30/30 [==============================] - 19s 608ms/step - loss: 0.5820 - acc: 0.7839 - f1_m: 0.7855 - precision_m: 0.8290 - recall_m: 0.7500 - val_loss: 0.8175 - val_acc: 0.6790 - val_f1_m: 0.6753 - val_precision_m: 0.7550 - val_recall_m: 0.6250
# Epoch 8/25
# 30/30 [==============================] - 19s 604ms/step - loss: 0.3959 - acc: 0.8686 - f1_m: 0.8602 - precision_m: 0.8873 - recall_m: 0.8375 - val_loss: 1.0242 - val_acc: 0.6667 - val_f1_m: 0.6693 - val_precision_m: 0.7129 - val_recall_m: 0.6364
# Epoch 9/25
# 30/30 [==============================] - 19s 608ms/step - loss: 0.4475 - acc: 0.8263 - f1_m: 0.8240 - precision_m: 0.8488 - recall_m: 0.8042 - val_loss: 1.0696 - val_acc: 0.7160 - val_f1_m: 0.6396 - val_precision_m: 0.6753 - val_recall_m: 0.6136
# Epoch 10/25
# 30/30 [==============================] - 19s 616ms/step - loss: 0.3977 - acc: 0.8644 - f1_m: 0.8545 - precision_m: 0.8845 - recall_m: 0.8292 - val_loss: 0.9865 - val_acc: 0.7531 - val_f1_m: 0.7503 - val_precision_m: 0.7798 - val_recall_m: 0.7273
# Epoch 11/25
# 30/30 [==============================] - 19s 606ms/step - loss: 0.3202 - acc: 0.8814 - f1_m: 0.8750 - precision_m: 0.8893 - recall_m: 0.8625 - val_loss: 0.8621 - val_acc: 0.7531 - val_f1_m: 0.7551 - val_precision_m: 0.7754 - val_recall_m: 0.7386
# Epoch 12/25
# 30/30 [==============================] - 19s 608ms/step - loss: 0.2998 - acc: 0.8898 - f1_m: 0.8810 - precision_m: 0.8980 - recall_m: 0.8667 - val_loss: 1.1069 - val_acc: 0.6914 - val_f1_m: 0.6876 - val_precision_m: 0.7213 - val_recall_m: 0.6591
# CPU times: user 5min 9s, sys: 40.9 s, total: 5min 50s
# Wall time: 5min 1s

# %%
# %%time

print("\n[INFO] Ready to train. Training is starting!\n")

hist_v3 = model_V3.fit(train_gen, validation_data=val_gen, epochs=25, callbacks=[callback])
# Out:
# [INFO] Ready to train. Training is starting!
#
# Epoch 1/25
# 30/30 [==============================] - 26s 633ms/step - loss: 1.6406 - acc: 0.3517 - f1_m: 0.3135 - precision_m: 0.3707 - recall_m: 0.2750 - val_loss: 1.2670 - val_acc: 0.4198 - val_f1_m: 0.0000e+00 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# Epoch 2/25
# 30/30 [==============================] - 18s 585ms/step - loss: 1.3560 - acc: 0.4619 - f1_m: 0.4602 - precision_m: 0.5218 - recall_m: 0.4167 - val_loss: 1.1946 - val_acc: 0.5556 - val_f1_m: 0.0000e+00 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# Epoch
# Epoch 14/25
# 30/30 [==============================] - 18s 614ms/step - loss: 0.6585 - acc: 0.7288 - f1_m: 0.7226 - precision_m: 0.7681 - recall_m: 0.6875 - val_loss: 0.7713 - val_acc: 0.6790 - val_f1_m: 0.6604 - val_precision_m: 0.7562 - val_recall_m: 0.6023
# Epoch 15/25
# 30/30 [==============================] - 18s 616ms/step - loss: 0.6828 - acc: 0.7246 - f1_m: 0.7151 - precision_m: 0.7587 - recall_m: 0.6792 - val_loss: 0.7795 - val_acc: 0.6543 - val_f1_m: 0.6613 - val_precision_m: 0.7477 - val_recall_m: 0.6023
# Epoch 16/25
# 30/30 [==============================] - 18s 593ms/step - loss: 0.5903 - acc: 0.7924 - f1_m: 0.7668 - precision_m: 0.8163 - recall_m: 0.7292 - val_loss: 0.7895 - val_acc: 0.6420 - val_f1_m: 0.6071 - val_precision_m: 0.6548 - val_recall_m: 0.5682
# Epoch 17/25
# 30/30 [==============================] - 17s 567ms/step - loss: 0.5792 - acc: 0.7754 - f1_m: 0.7521 - precision_m: 0.7955 - recall_m: 0.7167 - val_loss: 0.7898 - val_acc: 0.6296 - val_f1_m: 0.6780 - val_precision_m: 0.7321 - val_recall_m: 0.6364
# Epoch 18/25
# 30/30 [==============================] - 18s 586ms/step - loss: 0.6605 - acc: 0.7669 - f1_m: 0.7545 - precision_m: 0.7907 - recall_m: 0.7250 - val_loss: 0.7894 - val_acc: 0.6420 - val_f1_m: 0.5817 - val_precision_m: 0.6250 - val_recall_m: 0.5455
# Epoch 19/25
# 30/30 [==============================] - 17s 578ms/step - loss: 0.5265 - acc: 0.8051 - f1_m: 0.7994 - precision_m: 0.8375 - recall_m: 0.7708 - val_loss: 0.7956 - val_acc: 0.6420 - val_f1_m: 0.6583 - val_precision_m: 0.6724 - val_recall_m: 0.6477
# CPU times: user 4min 12s, sys: 1min 10s, total: 5min 23s
# Wall time: 5min 44s

# %%
# %%time

print("\n[INFO] Ready to train. Training is starting!\n")

hist_EfficientNet = model_EfficientNetB0_1.fit(train_gen, validation_data=val_gen, epochs=50)
# Out:
# [INFO] Ready to train. Training is starting!
#
# Epoch 1/50
# 30/30 [==============================] - 26s 655ms/step - loss: 1.5431 - acc: 0.2458 - f1_m: 0.0810 - precision_m: 0.2389 - recall_m: 0.0500 - val_loss: 1.3942 - val_acc: 0.2593 - val_f1_m: 0.0000e+00 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# Epoch 2/50
# 30/30 [==============================] - 17s 567ms/step - loss: 1.4784 - acc: 0.2754 - f1_m: 0.0606 - precision_m: 0.2133 - recall_m: 0.0375 - val_loss: 1.3861 - val_acc: 0.2593 - val_f1_m: 0.0000e+00 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# Epoch 3/50
# 30/30 [==============================] - 18s 597ms/step - loss: 1.6004 - acc: 0.2203 - f1_m: 0.0141 - precision_m: 0.0500 - recall_m: 0.0083 - val_loss: 1.3861 - val_acc: 0.2593 - val_f1_m: 0.0000e+00 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# Epoch 4/50
# 30/30 [==============================] - 17s 582ms/step - loss: 1.4537 - acc: 0.3093 - f1_m: 0.0815 - precision_m: 0.2333 - recall_m: 0.0500 - val_loss: 1.3843 - val_acc: 0.2593 - val_f1_m: 0.0000e+00 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# Epoch
- val_f1_m: 0.0000e+00 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# Epoch 47/50
# 30/30 [==============================] - 18s 595ms/step - loss: 1.4321 - acc: 0.2839 - f1_m: 0.0832 - precision_m: 0.2889 - recall_m: 0.0500 - val_loss: 1.3851 - val_acc: 0.2840 - val_f1_m: 0.0000e+00 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# Epoch 48/50
# 30/30 [==============================] - 18s 585ms/step - loss: 1.4567 - acc: 0.3178 - f1_m: 0.0824 - precision_m: 0.2611 - recall_m: 0.0500 - val_loss: 1.3691 - val_acc: 0.3086 - val_f1_m: 0.0000e+00 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# Epoch 49/50
# 30/30 [==============================] - 17s 569ms/step - loss: 1.5135 - acc: 0.2669 - f1_m: 0.0283 - precision_m: 0.1111 - recall_m: 0.0167 - val_loss: 1.3711 - val_acc: 0.2963 - val_f1_m: 0.0000e+00 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# Epoch 50/50
# 30/30 [==============================] - 17s 565ms/step - loss: 1.4417 - acc: 0.2415 - f1_m: 0.0496 - precision_m: 0.1833 - recall_m: 0.0292 - val_loss: 1.3679 - val_acc: 0.3580 - val_f1_m: 0.0000e+00 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# CPU times: user 10min 40s, sys: 2min 57s, total: 13min 37s
# Wall time: 14min 41s

# %%
# %%time

print("\n[INFO] Ready to train. Training is starting!\n")

hist_VGG = model_vgg16.fit(train_gen, validation_data=val_gen, epochs=50, callbacks=[callback])
# Out:
# [INFO] Ready to train. Training is starting!
#
# Epoch 1/50
# 30/30 [==============================] - 23s 625ms/step - loss: 1.4869 - acc: 0.2627 - f1_m: 0.1077 - precision_m: 0.3389 - recall_m: 0.0667 - val_loss: 1.3572 - val_acc: 0.3210 - val_f1_m: 0.0000e+00 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# Epoch 2/50
# 30/30 [==============================] - 18s 589ms/step - loss: 1.4257 - acc: 0.2924 - f1_m: 0.0805 - precision_m: 0.2361 - recall_m: 0.0500 - val_loss: 1.2971 - val_acc: 0.5432 - val_f1_m: 0.0000e+00 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# Epoch 3/50
# 30/30 [==============================] - 18s 583ms/step - loss: 1.4001 - acc: 0.3305 - f1_m: 0.0739 - precision_m: 0.2278 - recall_m: 0.0458 - val_loss: 1.2465 - val_acc: 0.6173 - val_f1_m: 0.0000e+00 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# Epoch 4/50
# 30/30 [==============================] - 18s 589ms/step - loss: 1.3583 - acc: 0.3178 - f1_m: 0.1067 - precision_m: 0.3244 - recall_m: 0.0667 - val_loss: 1.2063 - val_acc: 0.6296 - val_f1_m: 0.0000e+00 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# Epoch 5/50
# 30/30 [==============================] - 17s 567ms/step - loss: 1.2798 - acc: 0.4110 - f1_m: 0.1211 - precision_m: 0.3750 - recall_m: 0.0750 - val_loss: 1.1754 - val_acc: 0.6543 - val_f1_m: 0.0000e+00 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# Epoch 6/50
# 30/30 [==============================] - 17s 567ms/step - loss: 1.2167 - acc: 0.4703 - f1_m: 0.1663 - precision_m: 0.5667 - recall_m: 0.1000 - val_loss: 1.1438 - val_acc: 0.6790 - val_f1_m: 0.0000e+00 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# Epoch 7/50
# 30/30 [==============================] - 18s 586ms/step - loss: 1.2468 - acc: 0.4534 - f1_m: 0.1340 - precision_m: 0.3889 - recall_m: 0.0833 - val_loss: 1.1187 - val_acc: 0.6667 - val_f1_m: 0.1010 - val_precision_m: 0.4545 - val_recall_m: 0.0568
# Epoch 8/50
# 30/30 [==============================] - 17s 575ms/step - loss: 1.1959 - acc: 0.4873 - f1_m: 0.1274 - precision_m: 0.4000 - recall_m: 0.0792 - val_loss: 1.0940 - val_acc: 0.6173 - val_f1_m: 0.2867 - val_precision_m: 0.6061 - val_recall_m: 0.2159
# Epoch 49/50
# 30/30 [==============================] - 18s 591ms/step - loss: 0.7762 - acc: 0.6864 - f1_m: 0.6409 - precision_m: 0.8607 - recall_m: 0.5250 - val_loss: 0.7914 - val_acc: 0.7037 - val_f1_m: 0.7016 - val_precision_m: 0.8665 - val_recall_m: 0.6136
# Epoch 50/50
# 30/30 [==============================] - 18s 591ms/step - loss: 0.8120 - acc: 0.6822 - f1_m: 0.6115 - precision_m: 0.8285 - recall_m: 0.5083 - val_loss: 0.7750 - val_acc: 0.7160 - val_f1_m: 0.7204 - val_precision_m: 0.8955 - val_recall_m: 0.6136
# CPU times: user 10min 30s, sys: 3min 5s, total: 13min 36s
# Wall time: 14min 47s

# %%
# %%time

print("\n[INFO] Ready to train. Training is starting!\n")
hist_VGG19 = model_vgg19.fit(train_gen, validation_data=val_gen, epochs=50, callbacks=[callback])
# Out:
# [INFO] Ready to train. Training is starting!
#
# Epoch 1/50
# 30/30 [==============================] - 19s 595ms/step - loss: 1.4889 - acc: 0.2797 - f1_m: 0.1192 - precision_m: 0.3556 - recall_m: 0.0750 - val_loss: 1.3475 - val_acc: 0.3827 - val_f1_m: 0.0000e+00 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# Epoch 2/50
# 30/30 [==============================] - 17s 575ms/step - loss: 1.5047 - acc: 0.2542 - f1_m: 0.0836 - precision_m: 0.2139 - recall_m: 0.0542 - val_loss: 1.3206 - val_acc: 0.4938 - val_f1_m: 0.0000e+00 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# Epoch 3/50
# 30/30 [==============================] - 18s 615ms/step - loss: 1.3994 - acc: 0.3178 - f1_m: 0.0816 - precision_m: 0.2444 - recall_m: 0.0500 - val_loss: 1.2961 - val_acc: 0.4568 - val_f1_m: 0.0000e+00 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# Epoch 4/50
# 30/30 [==============================] - 18s 590ms/step - loss: 1.4269 - acc: 0.3051 - f1_m: 0.0861 - precision_m: 0.3444 - recall_m: 0.0500 - val_loss: 1.2756 - val_acc: 0.5432 - val_f1_m: 0.0000e+00 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# Epoch 5/50
# 30/30 [==============================] - 18s 592ms/step - loss: 1.3486 - acc: 0.3263 - f1_m: 0.1120 - precision_m: 0.3944 - recall_m: 0.0667 - val_loss: 1.2635 - val_acc: 0.4815 - val_f1_m: 0.0000e+00 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# Epoch 6/50
# 30/30 [==============================] - 17s 577ms/step - loss: 1.3186 - acc: 0.3559 - f1_m: 0.0893 - precision_m: 0.3000 - recall_m: 0.0542 - val_loss: 1.2421 - val_acc: 0.5556 - val_f1_m: 0.0000e+00 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# Epoch 7/50
# 30/30 [==============================] - 18s 584ms/step - loss: 1.2825 - acc: 0.4068 - f1_m: 0.0884 - precision_m: 0.2722 - recall_m: 0.0542 - val_loss: 1.2279 - val_acc: 0.5309 - val_f1_m: 0.0202 - val_precision_m: 0.0909 - val_recall_m: 0.0114
# Epoch 8/50
# 30/30 [==============================] - 17s 573ms/step - loss: 1.2900 - acc: 0.3729 - f1_m: 0.1079 - precision_m: 0.3278 - recall_m: 0.0667 - val_loss: 1.2096 - val_acc: 0.5309 - val_f1_m: 0.0404 - val_precision_m: 0.1818 - val_recall_m: 0.0227
# Epoch 9/50
# 30/30 [==============================] - 19s 618ms/step - loss: 1.0860 - acc: 0.5890 - f1_m: 0.3195 - precision_m: 0.8228 - recall_m: 0.2083 - val_loss: 1.0588 - val_acc: 0.6049 - val_f1_m: 0.3856 - val_precision_m: 0.6667 - val_recall_m: 0.2955
# Epoch 20/50
# 30/30 [==============================] - 18s 584ms/step - loss: 1.0925 - acc: 0.6017 - f1_m: 0.3487 - precision_m: 0.7083 - recall_m: 0.2375 - val_loss: 1.0516 - val_acc: 0.6296 - val_f1_m: 0.3659 - val_precision_m: 0.7500 - val_recall_m: 0.2500
# Epoch 21/50
# 30/30 [==============================] - 18s 589ms/step - loss: 1.0744 - acc: 0.6102 - f1_m: 0.3500 - precision_m: 0.7267 - recall_m: 0.2458 - val_loss: 1.0364 - val_acc: 0.6543 - val_f1_m: 0.3935 - val_precision_m: 0.9318 - val_recall_m: 0.2955
# Epoch 22/50
# 30/30 [==============================] - 17s 577ms/step - loss: 1.0660 - acc: 0.6102 - f1_m: 0.3484 - precision_m: 0.6833 - recall_m: 0.2458 - val_loss: 1.0438 - val_acc: 0.6049 - val_f1_m: 0.3290 - val_precision_m: 0.5697 - val_recall_m: 0.2386
# Epoch 23/50
# 30/30 [==============================] - 18s 600ms/step - loss: 1.0825 - acc: 0.5593 - f1_m: 0.3318 - precision_m: 0.6922 - recall_m: 0.2250 - val_loss: 1.0258 - val_acc: 0.6296 - val_f1_m: 0.3715 - val_precision_m: 0.7136 - val_recall_m: 0.2614
# Epoch 24/50
# 30/30 [==============================] - 17s 576ms/step - loss: 1.0477 - acc: 0.6271 - f1_m: 0.3975 - precision_m: 0.8389 - recall_m: 0.2750 - val_loss: 1.0226 - val_acc: 0.6296 - val_f1_m: 0.3955 - val_precision_m: 0.7273 - val_recall_m: 0.2841
# Epoch 25/50
# 30/30 [==============================] - 18s 582ms/step - loss: 1.0423 - acc: 0.5763 - f1_m: 0.3632 - precision_m: 0.8150 - recall_m: 0.2458 - val_loss: 1.0142 - val_acc: 0.6420 - val_f1_m: 0.4656 - val_precision_m: 0.7848 - val_recall_m: 0.3636
# Epoch 26/50
# 30/30 [==============================] - 18s 585ms/step - loss: 1.0322 - acc: 0.5890 - f1_m: 0.3721 - precision_m: 0.7250 - recall_m: 0.2667 - val_loss: 1.0098 - val_acc: 0.6296 - val_f1_m: 0.4003 - val_precision_m: 0.6530 - val_recall_m: 0.2955
# Epoch 27/50
# 30/30 [==============================] - 18s 597ms/step - loss: 1.0095 - acc: 0.6144 - f1_m: 0.4348 - precision_m: 0.8494 - recall_m: 0.3125 - val_loss: 1.0029 - val_acc: 0.6173 - val_f1_m: 0.4126 - val_precision_m: 0.6955 - val_recall_m: 0.3068
# Epoch 28/50
# 30/30 [==============================] - 17s 578ms/step - loss: 1.0056 - acc: 0.6229 - f1_m: 0.4220 - precision_m: 0.8189 - recall_m: 0.3042 - val_loss: 0.9937 - val_acc: 0.6173 - val_f1_m: 0.4283 - val_precision_m: 0.7333 - val_recall_m: 0.3182
# Epoch 29/50
# Epoch 49/50
# 30/30 [==============================] - 18s 583ms/step - loss: 0.8041 - acc: 0.7373 - f1_m: 0.5980 - precision_m: 0.8488 - recall_m: 0.4792 - val_loss: 0.8919 - val_acc: 0.6790 - val_f1_m: 0.5778 - val_precision_m: 0.7470 - val_recall_m: 0.4886
# Epoch 50/50
# 30/30 [==============================] - 17s 573ms/step - loss: 0.8640 - acc: 0.6949 - f1_m: 0.5929 - precision_m: 0.8207 - recall_m: 0.4792 - val_loss: 0.8915 - val_acc: 0.6790 - val_f1_m: 0.5941 - val_precision_m: 0.7998 - val_recall_m: 0.4886
# CPU times: user 10min 27s, sys: 3min 3s, total: 13min 31s
# Wall time: 14min 42s

# %%
hist_resNet = model_resnet.fit(train_gen, validation_data=val_gen, epochs=50)
# Out:
# Epoch 1/50
# 30/30 [==============================] - 49s 647ms/step - loss: 1.3294 - acc: 0.4746 - f1_m: 0.3879 - precision_m: 0.5286 - recall_m: 0.3208 - val_loss: 1.8687 - val_acc: 0.2469 - val_f1_m: 0.2288 - val_precision_m: 0.2305 - val_recall_m: 0.2273
# Epoch 2/50
# 30/30 [==============================] - 17s 572ms/step - loss: 0.7851 - acc: 0.7161 - f1_m: 0.6872 - precision_m: 0.7558 - recall_m: 0.6417 - val_loss: 6.3347 - val_acc: 0.2469 - val_f1_m: 0.2273 - val_precision_m: 0.2273 - val_recall_m: 0.2273
# Epoch 3/50
# 30/30 [==============================] - 17s 562ms/step - loss: 0.8477 - acc: 0.7119 - f1_m: 0.7070 - precision_m: 0.7498 - recall_m: 0.6750 - val_loss: 6.1403 - val_acc: 0.2469 - val_f1_m: 0.3068 - val_precision_m: 0.3068 - val_recall_m: 0.3068
# Epoch 4/50
# 30/30 [==============================] - 17s 559ms/step - loss: 0.5319 - acc: 0.7839 - f1_m: 0.7813 - precision_m: 0.8326 - recall_m: 0.7417 - val_loss: 3.5913 - val_acc: 0.2469 - val_f1_m: 0.2273 - val_precision_m: 0.2273 - val_recall_m: 0.2273
# Epoch 5/50
# 30/30 [==============================] - 17s 575ms/step - loss: 0.4988 - acc: 0.8093 - f1_m: 0.7991 - precision_m: 0.8226 - recall_m: 0.7792 - val_loss: 5.6433 - val_acc: 0.2469 - val_f1_m: 0.3068 - val_precision_m: 0.3068 - val_recall_m: 0.3068
# Epoch 6/50
# 30/30 [==============================] - 17s 558ms/step - loss: 0.4215 - acc: 0.8432 - f1_m: 0.8504 - precision_m: 0.9096 - recall_m: 0.8042 - val_loss: 2.1925 - val_acc: 0.2469 - val_f1_m: 0.3068 - val_precision_m: 0.3068 - val_recall_m: 0.3068
# Epoch 7/50
# 30/30 [==============================] - 18s 581ms/step - loss: 0.3477 - acc: 0.8729 - f1_m: 0.8674 - precision_m: 0.8831 - recall_m: 0.8542 - val_loss: 11.3717 - val_acc: 0.2469 - val_f1_m: 0.2273 - val_precision_m: 0.2273 - val_recall_m: 0.2273
# Epoch 8/50
# 30/30 [==============================] - 17s 562ms/step - loss: 0.4089 - acc: 0.8475 - f1_m: 0.8397 - precision_m: 0.8683 - recall_m: 0.8167 - val_loss: 1.4373 - val_acc: 0.3086 - val_f1_m: 0.0000e+00 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# Epoch 9/50
# 30/30 [==============================] - 17s 558ms/step - loss: 0.3995 - acc: 0.8475 - f1_m: 0.8308 - precision_m: 0.8518 - recall_m: 0.8125 - val_loss: 2.8125 - val_acc: 0.2469 - val_f1_m: 0.2273 - val_precision_m: 0.2273 - val_recall_m: 0.2273
# Epoch 10/50
# 30/30 [==============================] - 17s 555ms/step - loss: 0.4714 - acc: 0.8432 - f1_m: 0.8430 - precision_m: 0.8643 - recall_m: 0.8250 - val_loss: 2.0684 - val_acc: 0.2469 - val_f1_m: 0.3068 - val_precision_m: 0.3068 - val_recall_m: 0.3068
# Epoch 11/50
# 30/30 [==============================] - 17s 561ms/step - loss: 0.4249 - acc: 0.8517 - f1_m: 0.8415 - precision_m: 0.8768 - recall_m: 0.8125 - val_loss: 25.2480 - val_acc: 0.2593 - val_f1_m: 0.2386 - val_precision_m: 0.2386 - val_recall_m: 0.2386
# Epoch 12/50
# 30/30 [==============================] - 17s 571ms/step - loss: 0.3383 - acc: 0.8729 - f1_m: 0.8722 - precision_m: 0.8887 - recall_m: 0.8583 - val_loss: 1.7888 - val_acc: 0.2469 - val_f1_m: 0.0000e+00 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# Epoch 13/50
# 30/30 [==============================] - 17s 558ms/step - loss: 0.3224 - acc: 0.8856 - f1_m: 0.8845 - precision_m: 0.9024 - recall_m: 0.8708 - val_loss: 6.5348 - val_acc: 0.2469 - val_f1_m: 0.2273 - val_precision_m: 0.2273 - val_recall_m: 0.2273
# Epoch 14/50
# 30/30 [==============================] - 17s 559ms/step - loss: 0.3550 - acc: 0.8644 - f1_m: 0.8619 - precision_m: 0.8756 - recall_m: 0.8500 - val_loss: 3.0036 - val_acc: 0.2469 - val_f1_m: 0.2273 - val_precision_m: 0.2273 - val_recall_m: 0.2273
# Epoch 15/50
# 30/30 [==============================] - 17s 571ms/step - loss: 0.3291 - acc: 0.9153 - f1_m: 0.9075 - precision_m: 0.9208 - recall_m: 0.8958 - val_loss: 5.0042 - val_acc: 0.2469 - val_f1_m: 0.2273 - val_precision_m: 0.2273 - val_recall_m: 0.2273
# Epoch 16/50
# 30/30 [==============================] - 17s 551ms/step - loss: 0.2931 - acc: 0.8983 - f1_m: 0.8972 - precision_m: 0.9036 - recall_m: 0.8917 - val_loss: 2.1131 - val_acc: 0.2099 - val_f1_m: 0.1788 - val_precision_m: 0.1911 - val_recall_m: 0.1705
# Epoch 17/50
# 30/30 [==============================] - 17s 555ms/step - loss: 0.2883 - acc: 0.8983 - f1_m: 0.8917 - precision_m: 0.9107 - recall_m: 0.8792 - val_loss: 1.6966 - val_acc: 0.2469 - val_f1_m: 0.0813 - val_precision_m: 0.1439 - val_recall_m: 0.0568
# Epoch 18/50
# 30/30 [==============================] - 18s 578ms/step - loss: 0.3160 - acc: 0.8856 - f1_m: 0.8889 - precision_m: 0.8952 - recall_m: 0.8833 - val_loss: 1.7148 - val_acc: 0.2593 - val_f1_m: 0.1828 - val_precision_m: 0.2231 - val_recall_m: 0.1591
# Epoch 19/50
# 30/30 [==============================] - 17s 560ms/step - loss: 0.3644 - acc: 0.8729 - f1_m: 0.8783 - precision_m: 0.8917 - recall_m: 0.8667 - val_loss: 2.1528 - val_acc: 0.2469 - val_f1_m: 0.2280 - val_precision_m: 0.2289 - val_recall_m: 0.2273
# Epoch 20/50
# 30/30 [==============================] - 17s 553ms/step - loss: 0.2614 - acc: 0.9280 - f1_m: 0.9216 - precision_m: 0.9327 - recall_m: 0.9125 - val_loss: 2.2952 - val_acc: 0.2469 - val_f1_m: 0.2303 - val_precision_m: 0.2338 - val_recall_m: 0.2273
# Epoch 21/50
# 30/30 [==============================] - 18s 602ms/step - loss: 0.2119 - acc: 0.9153 - f1_m: 0.9183 - precision_m: 0.9250 - recall_m: 0.9125 - val_loss: 1.9140 - val_acc: 0.2469 - val_f1_m: 0.1563 - val_precision_m: 0.2182 - val_recall_m: 0.1250
# Epoch 22/50
# 30/30 [==============================] - 17s 566ms/step - loss: 0.2049 - acc: 0.9449 - f1_m: 0.9359 - precision_m: 0.9494 - recall_m: 0.9250 - val_loss: 2.4219 - val_acc: 0.2963 - val_f1_m: 0.2369 - val_precision_m: 0.2649 - val_recall_m: 0.2159
# Epoch 23/50
# 30/30 [==============================] - 17s 574ms/step - loss: 0.2209 - acc: 0.9322 - f1_m: 0.9269 - precision_m: 0.9292 - recall_m: 0.9250 - val_loss: 2.8412 - val_acc: 0.3086 - val_f1_m: 0.2282 - val_precision_m: 0.2647 - val_recall_m: 0.2045
# Epoch 24/50
# 30/30 [==============================] - 18s 576ms/step - loss: 0.1859 - acc: 0.9364 - f1_m: 0.9364 - precision_m: 0.9446 - recall_m: 0.9292 - val_loss: 2.0381 - val_acc: 0.2963 - val_f1_m: 0.2456 - val_precision_m: 0.2870 - val_recall_m: 0.2159
# Epoch 25/50
# 30/30 [==============================] - 18s 587ms/step - loss: 0.1957 - acc: 0.9576 - f1_m: 0.9514 - precision_m: 0.9577 - recall_m: 0.9458 - val_loss: 2.4915 - val_acc: 0.2716 - val_f1_m: 0.2470 - val_precision_m: 0.2565 - val_recall_m: 0.2386
# Epoch 26/50
# 30/30 [==============================] - 18s 578ms/step - loss: 0.1772 - acc: 0.9280 - f1_m: 0.9278 - precision_m: 0.9405 - recall_m: 0.9167 - val_loss: 2.2256 - val_acc: 0.2840 - val_f1_m: 0.3443 - val_precision_m: 0.3620 - val_recall_m: 0.3295
# Epoch 27/50
# 30/30 [==============================] - 17s 560ms/step - loss: 0.1669 - acc: 0.9364 - f1_m: 0.9400 - precision_m: 0.9577 - recall_m: 0.9250 - val_loss: 2.5853 - val_acc: 0.2593 - val_f1_m: 0.2311 - val_precision_m: 0.2354 - val_recall_m: 0.2273
# Epoch 28/50
# 30/30 [==============================] - 18s 580ms/step - loss: 0.1509 - acc: 0.9661 - f1_m: 0.9575 - precision_m: 0.9661 - recall_m: 0.9500 - val_loss: 1.8528 - val_acc: 0.1975 - val_f1_m: 0.1674 - val_precision_m: 0.1989 - val_recall_m: 0.1477
# Epoch 29/50
# 30/30 [==============================] - 18s 577ms/step - loss: 0.1749 - acc: 0.9407 - f1_m: 0.9389 - precision_m: 0.9452 - recall_m: 0.9333 - val_loss: 1.6920 - val_acc: 0.2963 - val_f1_m: 0.2347 - val_precision_m: 0.2610 - val_recall_m: 0.2159
# Epoch 30/50
# 30/30 [==============================] - 17s 566ms/step - loss: 0.1413 - acc: 0.9576 - f1_m: 0.9533 - precision_m: 0.9571 - recall_m: 0.9500 - val_loss: 1.9045 - val_acc: 0.3333 - val_f1_m: 0.2788 - val_precision_m: 0.3229 - val_recall_m: 0.2500
# Epoch 31/50
# 30/30 [==============================] - 17s 560ms/step - loss: 0.1732 - acc: 0.9407 - f1_m: 0.9405 - precision_m: 0.9542 - recall_m: 0.9292 - val_loss: 1.3353 - val_acc: 0.4568 - val_f1_m: 0.5302 - val_precision_m: 0.5947 - val_recall_m: 0.4886
# Epoch 32/50
# 30/30 [==============================] - 17s 573ms/step - loss: 0.1250 - acc: 0.9534 - f1_m: 0.9578 - precision_m: 0.9667 - recall_m: 0.9500 - val_loss: 1.7926 - val_acc: 0.4938 - val_f1_m: 0.4521 - val_precision_m: 0.4800 - val_recall_m: 0.4318
# Epoch 33/50
# 30/30 [==============================] - 17s 564ms/step - loss: 0.1453 - acc: 0.9492 - f1_m: 0.9453 - precision_m: 0.9494 - recall_m: 0.9417 - val_loss: 1.7971 - val_acc: 0.5926 - val_f1_m: 0.5048 - val_precision_m: 0.5399 - val_recall_m: 0.4773
# Epoch 34/50
# 30/30 [==============================] - 17s 585ms/step - loss: 0.1749 - acc: 0.9492 - f1_m: 0.9446 - precision_m: 0.9486 - recall_m: 0.9417 - val_loss: 1.8035 - val_acc: 0.5926 - val_f1_m: 0.5359 - val_precision_m: 0.5519 - val_recall_m: 0.5227
# Epoch 35/50
# 30/30 [==============================] - 18s 589ms/step - loss: 0.0966 - acc: 0.9661 - f1_m: 0.9633 - precision_m: 0.9690 - recall_m: 0.9583 - val_loss: 1.6309 - val_acc: 0.5926 - val_f1_m: 0.6239 - val_precision_m: 0.6369 - val_recall_m: 0.6136
# Epoch 36/50
# 30/30 [==============================] - 18s 599ms/step - loss: 0.0780 - acc: 0.9746 - f1_m: 0.9706 - precision_m: 0.9750 - recall_m: 0.9667 - val_loss: 0.8761 - val_acc: 0.7407 - val_f1_m: 0.7568 - val_precision_m: 0.7646 - val_recall_m: 0.7500
# Epoch 37/50
# 30/30 [==============================] - 18s 585ms/step - loss: 0.0675 - acc: 0.9703 - f1_m: 0.9744 - precision_m: 0.9786 - recall_m: 0.9708 - val_loss: 1.4289 - val_acc: 0.7160 - val_f1_m: 0.7386 - val_precision_m: 0.7386 - val_recall_m: 0.7386
# Epoch 38/50
# 30/30 [==============================] - 18s 580ms/step - loss: 0.1204 - acc: 0.9407 - f1_m: 0.9469 - precision_m: 0.9530 - recall_m: 0.9417 - val_loss: 1.6654 - val_acc: 0.7407 - val_f1_m: 0.6818 - val_precision_m: 0.6818 - val_recall_m: 0.6818
# Epoch 39/50
# 30/30 [==============================] - 18s 583ms/step - loss: 0.1306 - acc: 0.9576 - f1_m: 0.9597 - precision_m: 0.9667 - recall_m: 0.9542 - val_loss: 1.5476 - val_acc: 0.6543 - val_f1_m: 0.6889 - val_precision_m: 0.6975 - val_recall_m: 0.6818
# Epoch 40/50
# 30/30 [==============================] - 17s 563ms/step - loss: 0.1018 - acc: 0.9831 - f1_m: 0.9786 - precision_m: 0.9833 - recall_m: 0.9750 - val_loss: 0.8011 - val_acc: 0.8148 - val_f1_m: 0.8280 - val_precision_m: 0.8393 - val_recall_m: 0.8182
# Epoch 41/50
# 30/30 [==============================] - 17s 573ms/step - loss: 0.0836 - acc: 0.9619 - f1_m: 0.9622 - precision_m: 0.9667 - recall_m: 0.9583 - val_loss: 1.0411 - val_acc: 0.8025 - val_f1_m: 0.7386 - val_precision_m: 0.7386 - val_recall_m: 0.7386
# Epoch 42/50
# 30/30 [==============================] - 17s 574ms/step - loss: 0.1950 - acc: 0.9364 - f1_m: 0.9355 - precision_m: 0.9435 - recall_m: 0.9292 - val_loss: 2.4591 - val_acc: 0.5802 - val_f1_m: 0.5379 - val_precision_m: 0.5422 - val_recall_m: 0.5341
# Epoch 43/50
# 30/30 [==============================] - 17s 573ms/step - loss: 0.1175 - acc: 0.9576 - f1_m: 0.9622 - precision_m: 0.9667 - recall_m: 0.9583 - val_loss: 6.7764 - val_acc: 0.4691 - val_f1_m: 0.5197 - val_precision_m: 0.5292 - val_recall_m: 0.5114
# Epoch 44/50
# 30/30 [==============================] - 17s 566ms/step - loss: 0.1538 - acc: 0.9322 - f1_m: 0.9363 - precision_m: 0.9452 - recall_m: 0.9292 - val_loss: 2.7758 - val_acc: 0.6296 - val_f1_m: 0.5712 - val_precision_m: 0.5747 - val_recall_m: 0.5682
# Epoch 45/50
# 30/30 [==============================] - 17s 560ms/step - loss: 0.1882 - acc: 0.9492 - f1_m: 0.9411 - precision_m: 0.9452 - recall_m: 0.9375 - val_loss: 3.4167 - val_acc: 0.5679 - val_f1_m: 0.6136 - val_precision_m: 0.6266 - val_recall_m: 0.6023
# Epoch 46/50
# 30/30 [==============================] - 18s 579ms/step - loss: 0.2155 - acc: 0.9322 - f1_m: 0.9290 - precision_m: 0.9389 - recall_m: 0.9208 - val_loss: 1.2414 - val_acc: 0.7160 - val_f1_m: 0.7333 - val_precision_m: 0.7403 - val_recall_m: 0.7273
# Epoch 47/50
# 30/30 [==============================] - 17s 564ms/step - loss: 0.0700 - acc: 0.9831 - f1_m: 0.9789 - precision_m: 0.9833 - recall_m: 0.9750 - val_loss: 0.8656 - val_acc: 0.7901 - val_f1_m: 0.7909 - val_precision_m: 0.7987 - val_recall_m: 0.7841
# Epoch 48/50
# 30/30 [==============================] - 17s 562ms/step - loss: 0.0882 - acc: 0.9703 - f1_m: 0.9683 - precision_m: 0.9702 - recall_m: 0.9667 - val_loss: 1.6683 - val_acc: 0.7284 - val_f1_m: 0.7432 - val_precision_m: 0.7484 - val_recall_m: 0.7386
# Epoch 49/50
# 30/30 [==============================] - 18s 579ms/step - loss: 0.1721 - acc: 0.9364 - f1_m: 0.9353 - precision_m: 0.9375 - recall_m: 0.9333 - val_loss: 0.8273 - val_acc: 0.7778 - val_f1_m: 0.6955 - val_precision_m: 0.7110 - val_recall_m: 0.6818
# Epoch 50/50
# 30/30 [==============================] - 17s 569ms/step - loss: 0.1251 - acc: 0.9492 - f1_m: 0.9452 - precision_m: 0.9500 - recall_m: 0.9417 - val_loss: 12.0368 - val_acc: 0.4074 - val_f1_m: 0.3750 - val_precision_m: 0.3750 - val_recall_m: 0.3750

# %%
#hist_resNet = model_resnet2.fit(train_gen, validation_data=val_gen, epochs=50, callbacks=[callback])

# %%
# %%time

print("\n[INFO] Ready to train. Training is starting!\n")
# Out:
# [INFO] Ready to train. Training is starting!
#
# CPU times: user 384 µs, sys: 0 ns, total: 384 µs
# Wall time: 374 µs

# %% [markdown]
# # Evaluacion de modelos

# %%
cm_xception = check_precision(model_V3,test_generator)
# Out:
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 1s 1s/step
# Matriz de Confusión:
# [[13  5  1  2]
#  [ 1 11  4  4]
#  [ 0  5 14  2]
#  [ 8  1  1 11]]
# Precisión: 0.5903614457831325

# %% [markdown]
# ## Guardar modelos

# %%
# Specify the directory to save the models
save_dir = '/content/drive/My Drive/SavedModels'

# %%
# Ensure the directory exists, create it if necessary
#os.makedirs(save_dir, exist_ok=True)

# Save Xception model
#xception_model.save(os.path.join(save_dir, 'xception_model.h5'))

# Save EfficientNetB0 model
#model_EfficientNetB0_1.save(os.path.join(save_dir, 'efficientnet_model.h5'))

# Save V3 model
#model_V3.save(os.path.join(save_dir, 'inceptionv3_model.h5'))

# Save VGG model
#model_vgg16.save(os.path.join(save_dir, 'vgg_model16.h5'))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# # validacion de resultados

# %%
import matplotlib.pyplot as plt

def plot_hist(hist):
    # Crear la figura y los ejes
    fig, ax = plt.subplots(figsize=(10, 6))

    # Plotear accuracy y val_accuracy
    ax.plot(hist.history["acc"], label="Train Accuracy", color="blue", linestyle="-")
    ax.plot(hist.history["val_acc"], label="Validation Accuracy", color="blue", linestyle="--")

    # Plotear precision_m y val_precision_m
    ax.plot(hist.history["precision_m"], label="Train Precision", color="green", linestyle="-")
    ax.plot(hist.history["val_precision_m"], label="Validation Precision", color="green", linestyle="--")

    # Configurar el subplot
    ax.set_title("Model Metrics")
    ax.set_ylabel("Metrics")
    ax.set_xlabel("Epoch")
    ax.legend(loc="upper left")

    # Mostrar la gráfica
    plt.show()

# Ejemplo de uso:
# Suponiendo que `history` es el objeto devuelto por el entrenamiento del modelo
# model.fit(...)
# plot_hist(history)

# %%
import matplotlib.pyplot as plt

def plot_metrics_loss_f1(histories, names):
    fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(18, 10))
    fig.suptitle('Model Metrics Comparison', fontsize=16)

    for i, (history, name) in enumerate(zip(histories, names)):
        # Pérdida
        axes[i//3, i%3].plot(history.history['loss'], label='Train Loss', color='blue', linestyle='-')
        axes[i//3, i%3].plot(history.history['val_loss'], label='Validation Loss', color='blue', linestyle='--')

        # F1 Score
        axes[i//3, i%3].plot(history.history['f1_m'], label='Train F1 Score', color='orange', linestyle='-')
        axes[i//3, i%3].plot(history.history['val_f1_m'], label='Validation F1 Score', color='orange', linestyle='--')

        axes[i//3, i%3].set_title(name)
        axes[i//3, i%3].set_xlabel('Epoch')
        axes[i//3, i%3].set_ylabel('Metrics')
        axes[i//3, i%3].legend()

    plt.tight_layout(rect=[0, 0, 1, 0.96])
    plt.show()

# Ejemplo de uso:
# Suponiendo que `histories` y `nombres` son las listas proporcionadas
# plot_metrics(historias, nombres)

# %%
import matplotlib.pyplot as plt

def plot_accuracy_and_precision(histories, names):
    fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(18, 10))
    fig.suptitle('Accuracy and Precision Comparison', fontsize=16)

    for i, (history, name) in enumerate(zip(histories, names)):
        # Plotear accuracy y val_accuracy
        axes[i//3, i%3].plot(history.history["acc"], label="Train Accuracy", color="blue", linestyle="-")
        axes[i//3, i%3].plot(history.history["val_acc"], label="Validation Accuracy", color="blue", linestyle="--")

        # Plotear precision_m y val_precision_m
        axes[i//3, i%3].plot(history.history["precision_m"], label="Train Precision", color="green", linestyle="-")
        axes[i//3, i%3].plot(history.history["val_precision_m"], label="Validation Precision", color="green", linestyle="--")

        axes[i//3, i%3].set_title(name)
        axes[i//3, i%3].set_xlabel('Epoch')
        axes[i//3, i%3].set_ylabel('Metrics')
        axes[i//3, i%3].legend()

    plt.tight_layout(rect=[0, 0, 1, 0.96])
    plt.show()

# Ejemplo de uso:
# Suponiendo que `histories` y `names` son las listas proporcionadas
# plot_accuracy_and_precision(histories, names)

# %%
test_gen = ImageDataGenerator(rescale=1/255.)
test_generator = test_gen.flow_from_directory(directory=test_dir, target_size=IMG_SIZE, batch_size=8, class_mode='categorical')

cm_xception = check_precision(xception_model,test_generator)
# Out:
# Found 83 images belonging to 4 classes.
# 1/1 [==============================] - 1s 756ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 1s 1s/step
# Matriz de Confusión:
# [[13  5  3  0]
#  [ 1 15  3  1]
#  [ 0  1 20  0]
#  [ 0  0  6 15]]
# Precisión: 0.7590361445783133

# %%
# Eliminar los historiales no deseados
historias = [hist_xception, hist_v3, hist_EfficientNet, hist_VGG, hist_VGG19, hist_resNet]
nombres = ['Xception', 'V3', 'EfficientNet', 'VGG16', 'VGG19', 'ResNet']

# %%
plot_accuracy_and_precision(historias,nombres)

# %%
import pandas as pd
from sklearn.metrics import classification_report

def evaluar_modelos(modelos, nombres_modelos, test_generator):
    resultados = {'Modelo': [], 'Precisión': [], 'Recall': [], 'F1': []}

    for modelo, nombre_modelo in zip(modelos, nombres_modelos):
        # Evaluación en el conjunto de prueba
        evaluation = modelo.evaluate(test_generator)

        # Obtener las predicciones para calcular otras métricas
        predictions = modelo.predict(test_generator)

        # Calcular métricas adicionales usando classification_report de scikit-learn
        report = classification_report(test_generator.classes, predictions.argmax(axis=1), target_names=test_generator.class_indices)

        # Obtener las métricas específicas de interés
        precision = evaluation[1]
        recall = float(report.split()[-4])
        f1 = float(report.split()[-2])

        # Almacenar resultados en el diccionario
        resultados['Modelo'].append(nombre_modelo)
        resultados['Precisión'].append(precision)
        resultados['Recall'].append(recall)
        resultados['F1'].append(f1)

    # Crear un DataFrame con los valores de las métricas
    df_resultados = pd.DataFrame(resultados)

    return df_resultados

# %%
modelos = [model_resnet, model_vgg19, model_vgg16, model_EfficientNetB0_1, model_V3, xception_model]
nombres_modelos = ['ResNet', 'VGG19', 'VGG16', 'EfficientNetB0_1', 'V3', 'Xception']

df_resultados = evaluar_modelos(modelos, nombres_modelos, test_generator)

# Muestra el DataFrame
print(df_resultados)
# Out:
# 11/11 [==============================] - 3s 212ms/step - loss: 9.3923 - acc: 0.3855 - f1_m: 0.3727 - precision_m: 0.3745 - recall_m: 0.3712
# 11/11 [==============================] - 2s 207ms/step
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 11/11 [==============================] - 3s 220ms/step - loss: 0.9762 - acc: 0.6024 - f1_m: 0.4899 - precision_m: 0.7348 - recall_m: 0.3826
# 11/11 [==============================] - 2s 217ms/step
# 11/11 [==============================] - 3s 219ms/step - loss: 1.0033 - acc: 0.5783 - f1_m: 0.5071 - precision_m: 0.6758 - recall_m: 0.4167
# 11/11 [==============================] - 2s 210ms/step
# 11/11 [==============================] - 3s 229ms/step - loss: 1.3400 - acc: 0.2892 - f1_m: 0.0000e+00 - precision_m: 0.0000e+00 - recall_m: 0.0000e+00
# 11/11 [==============================] - 3s 219ms/step
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 11/11 [==============================] - 2s 205ms/step - loss: 1.1342 - acc: 0.5904 - f1_m: 0.5886 - precision_m: 0.6185 - recall_m: 0.5644
# 11/11 [==============================] - 2s 206ms/step
# 11/11 [==============================] - 2s 203ms/step - loss: 0.7149 - acc: 0.7590 - f1_m: 0.7810 - precision_m: 0.8058 - recall_m: 0.7614
# 11/11 [==============================] - 3s 228ms/step
#              Modelo  Precisión  Recall    F1
# 0            ResNet   0.385542    0.12  0.15
# 1             VGG19   0.602410    0.21  0.20
# 2             VGG16   0.578313    0.27  0.27
# 3  EfficientNetB0_1   0.289157    0.18  0.19
# 4                V3   0.590361    0.29  0.29
# 5          Xception   0.759036    0.13  0.13

# %%
from tabulate import tabulate

def imprimir_tabla(df_resultados):
    print(tabulate(df_resultados, headers='keys', tablefmt='pretty', showindex=False))

# Ejemplo de uso
imprimir_tabla(df_resultados)
# Out:
# +------------------+---------------------+--------+------+
# |      Modelo      |      Precisión      | Recall |  F1  |
# +------------------+---------------------+--------+------+
# |      ResNet      | 0.3855421543121338  |  0.12  | 0.15 |
# |      VGG19       | 0.6024096608161926  |  0.21  | 0.2  |
# |      VGG16       | 0.5783132314682007  |  0.27  | 0.27 |
# | EfficientNetB0_1 | 0.28915661573410034 |  0.18  | 0.19 |
# |        V3        | 0.5903614163398743  |  0.29  | 0.29 |
# |     Xception     |  0.759036123752594  |  0.13  | 0.13 |
# +------------------+---------------------+--------+------+

# %%
# Specify the directory to save the models
save_dir = '/content/drive/My Drive/SavedModels'

# Ensure the directory exists, create it if necessary
os.makedirs(save_dir, exist_ok=True)

# Save Xception model
xception_model.save(os.path.join(save_dir, 'xception_model_v2_384x612.h5'))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
plot_metrics_loss_f1(historias,nombres)

# %%
plot_confusion_matrix(cm_xception, classes)
